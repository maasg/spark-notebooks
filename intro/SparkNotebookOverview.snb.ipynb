// %% [markdown]
// # Spark Notebook
// ## Interactive Data Analysis with backed by Apache Spark

// %% [markdown]
// The Spark Notebook is the open source notebook focusing on improving productivity of data analitycs and data science in enterprise environments.
//
// For that, it is only based on JVM components and has no other dependencies.
//
// It uses Scala as its main language to benefit from the JVM ecosystem blended with a functional approach and full access to all Spark features. The Spark Notebook enriches the data analytics experience with reactive charts and plotting elements that provide visual insights in the data.

// %% [markdown]
// ---
// ## Multiple Independent Spark Contexts

// %% [markdown]
// One of the top most useful feature brought by the spark notebook is its separation of the running notebooks.
//
// Indeed, each started notebook will spawn a new JVM with its own `SparkSession` instance. This allows a maximal flexibility for:
// * dependencies without clashes
// * access different clusters
// * tune differently each notebook
// * external scheduling (on the roadmap)

// %% [markdown]
// You can recognize easily the spawned processes using `ps` (*unix* only) and search for the main class `ChildProcessMain` and verify that the process contains the name of the started notebooks.

// %%
import sys.process._
import scala.language.postfixOps
"ps aux" #| "grep ChildProcessMain" lineStream_!
// Out:
// import sys.process._
// import scala.language.postfixOps
// res5: Stream[String] = Stream(maasg     5360  0.5  8.5 9478024 1379380 pts/1 Sl+  Sep25   4:57 /usr/lib/jvm/java-8-oracle/jre/bin/java -Xmx3674210304 -XX:MaxPermSize=1073741824 -server notebook.kernel.pfork.ChildProcessMain notebook.kernel.remote.RemoteActorProcess 35989 info 94cbf08e-1547-418e-b5f1-d0fcd36cd3eb ngrams/language-detection-letter-freq.snb NONE kernel, ?)
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon32412a170e746706761c1426c1155e57&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;1258856810&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul1258856810"><li>
//               <a href="#tab1258856810-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab1258856810-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab1258856810"><div class="tab-pane" id="tab1258856810-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon2f0efcc9912d6a932c84e38cc65807b6&quot;,&quot;dataInit&quot;:[{&quot;string value&quot;:&quot;maasg     5360  0.5  8.5 9478024 1379380 pts/1 Sl+  Sep25   4:57 /usr/lib/jvm/java-8-oracle/jre/bin/java -Xmx3674210304 -XX:MaxPermSize=1073741824 -server notebook.kernel.pfork.ChildProcessMain notebook.kernel.remote.RemoteActorProcess 35989 info 94cbf08e-1547-418e-b5f1-d0fcd36cd3eb ngrams/language-detection-letter-freq.snb NONE kernel&quot;},{&quot;string value&quot;:&quot;maasg     7247  0.4  6.6 9403964 1072140 pts/1 Sl+  Sep25   3:26 /usr/lib/jvm/java-8-oracle/jre/bin/java -Xmx3674210304 -XX:MaxPermSize=1073741824 -server notebook.kernel.pfork.ChildProcessMain notebook.kernel.remote.RemoteActorProcess 34477 info 10a1e547-2a02-4a7a-87e4-21a0eddc81fc ngrams/language-detection-letter-freq1.snb.ipynb NONE kernel&quot;},{&quot;string value&quot;:&quot;maasg     7420  0.7 14.1 9534396 2276144 pts/1 Sl+  Sep25   6:28 /usr/lib/jvm/java-8-oracle/jre/bin/java -Xmx3674210304 -XX:MaxPermSize=1073741824 -server notebook.kernel.pfork.ChildProcessMain notebook.kernel.remote.RemoteActorProcess 39289 info c392b82e-caf4-4a46-af4b-f62c76891c1a ngrams/language-detection-letter-freq1.snb.ipynb NONE kernel&quot;},{&quot;string value&quot;:&quot;maasg    24215  2.8  6.9 9404992 1123976 pts/1 Sl+  12:04   1:47 /usr/lib/jvm/java-8-oracle/jre/bin/java -Xmx3674210304 -XX:MaxPermSize=1073741824 -server notebook.kernel.pfork.ChildProcessMain notebook.kernel.remote.RemoteActorProcess 41327 info cfb614fa-a222-4b28-8800-180320b5793a intro/otto-demo.snb NONE kernel&quot;},{&quot;string value&quot;:&quot;maasg    24505  3.8  8.1 9440160 1310164 pts/1 Sl+  12:06   2:15 /usr/lib/jvm/java-8-oracle/jre/bin/java -Xmx3674210304 -XX:MaxPermSize=1073741824 -server notebook.kernel.pfork.ChildProcessMain notebook.kernel.remote.RemoteActorProcess 42311 info 847ee71b-19b4-4770-9525-ce43bb14e147 \&quot;intro/Why Spark Notebook GM.snb\&quot; NONE kernel&quot;},{&quot;string value&quot;:&quot;maasg    28741  0.0  0.0  14748  2748 pts/1    S+   13:06   0:00 grep ChildProcessMain&quot;}],&quot;genId&quot;:&quot;2006303921&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["string value"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon0a969cca43f580164227bac0ddeadd53&quot;,&quot;initialValue&quot;:&quot;6&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon894a39c29576b823554adde58226afd2&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1258856810-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon3c831cfb570b250355c50f2c8866070b&quot;,&quot;dataInit&quot;:[{&quot;string value&quot;:&quot;maasg     5360  0.5  8.5 9478024 1379380 pts/1 Sl+  Sep25   4:57 /usr/lib/jvm/java-8-oracle/jre/bin/java -Xmx3674210304 -XX:MaxPermSize=1073741824 -server notebook.kernel.pfork.ChildProcessMain notebook.kernel.remote.RemoteActorProcess 35989 info 94cbf08e-1547-418e-b5f1-d0fcd36cd3eb ngrams/language-detection-letter-freq.snb NONE kernel&quot;},{&quot;string value&quot;:&quot;maasg     7247  0.4  6.6 9403964 1072140 pts/1 Sl+  Sep25   3:26 /usr/lib/jvm/java-8-oracle/jre/bin/java -Xmx3674210304 -XX:MaxPermSize=1073741824 -server notebook.kernel.pfork.ChildProcessMain notebook.kernel.remote.RemoteActorProcess 34477 info 10a1e547-2a02-4a7a-87e4-21a0eddc81fc ngrams/language-detection-letter-freq1.snb.ipynb NONE kernel&quot;},{&quot;string value&quot;:&quot;maasg     7420  0.7 14.1 9534396 2276144 pts/1 Sl+  Sep25   6:28 /usr/lib/jvm/java-8-oracle/jre/bin/java -Xmx3674210304 -XX:MaxPermSize=1073741824 -server notebook.kernel.pfork.ChildProcessMain notebook.kernel.remote.RemoteActorProcess 39289 info c392b82e-caf4-4a46-af4b-f62c76891c1a ngrams/language-detection-letter-freq1.snb.ipynb NONE kernel&quot;},{&quot;string value&quot;:&quot;maasg    24215  2.8  6.9 9404992 1123976 pts/1 Sl+  12:04   1:47 /usr/lib/jvm/java-8-oracle/jre/bin/java -Xmx3674210304 -XX:MaxPermSize=1073741824 -server notebook.kernel.pfork.ChildProcessMain notebook.kernel.remote.RemoteActorProcess 41327 info cfb614fa-a222-4b28-8800-180320b5793a intro/otto-demo.snb NONE kernel&quot;},{&quot;string value&quot;:&quot;maasg    24505  3.8  8.1 9440160 1310164 pts/1 Sl+  12:06   2:15 /usr/lib/jvm/java-8-oracle/jre/bin/java -Xmx3674210304 -XX:MaxPermSize=1073741824 -server notebook.kernel.pfork.ChildProcessMain notebook.kernel.remote.RemoteActorProcess 42311 info 847ee71b-19b4-4770-9525-ce43bb14e147 \&quot;intro/Why Spark Notebook GM.snb\&quot; NONE kernel&quot;},{&quot;string value&quot;:&quot;maasg    28741  0.0  0.0  14748  2748 pts/1    S+   13:06   0:00 grep ChildProcessMain&quot;}],&quot;genId&quot;:&quot;312998180&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span

// %% [markdown]
// So this notebook declares the variables `sparkSession` and `sparkContext` (with its alias `sc`).

// %%
val context = (sparkSession, sparkContext, sc)
// Out:
// context: (org.apache.spark.sql.SparkSession, org.apache.spark.SparkContext, org.apache.spark.SparkContext) = (org.apache.spark.sql.SparkSession@1988ee55,org.apache.spark.SparkContext@662a71ba,org.apache.spark.SparkContext@662a71ba)

// %% [markdown]
// Internally, are declared as `var`s. We need a little trick when we want to import implicits (typical when using `DataFrame`s and `Dataset`s

// %%
val spark = sparkSession
import spark.implicits._
// Out:
// spark: org.apache.spark.sql.SparkSession = org.apache.spark.sql.SparkSession@1988ee55
// import spark.implicits._

// %% [markdown]
// ### Spark Configuration

// %% [markdown]
// The metadata can define a JSON object (String to String!) to declare extra configuration for spark.

// %%
sparkSession.conf.get("spark.default.parallelism")
// Out:
// res12: String = 4
// 4

// %% [markdown]
// ### Managing of Library Dependencies
// #### Enrich your notebook with any library available out there

// %% [markdown]
// This notebook has injected a few dependencies from the [datastax cassandra connector](https://github.com/datastax/spark-cassandra-connector/).

// %% [markdown]
// Hence, this code compiles.

// %%
import com.datastax.spark.connector._
// Out:
// import com.datastax.spark.connector._

// %% [markdown]
// Also it includes the kafka external modules for the current scala version (using `%%`) and the current spark version (using `_`)

// %%
import org.apache.spark.streaming.kafka
// Out:
// import org.apache.spark.streaming.kafka

// %% [markdown]
// We can also see that we can remove dependencies by prepending `-` to the definition. So we avoid downloading any extra libraries from the scala language.

// %% [markdown]
// ### Change the metadata

// %% [markdown]
// There are a few metadata available and you can configure them from the editor in the menu: _Edit > Edit Notebook Metadata_.

// %% [markdown]
// ---
// ## Plotting

// %% [markdown]
// There exist many predefined `Chart` that you can use directly on any kind of **Scala** container that can be iterated.

// %% [markdown]
// If the last statement of a cell isn't an assignment or a definition, then the spark notebook will try to plot it the best way it can automatically.

// %%
case class Example(id:Int, category:String, value:Long, advanced:Boolean)
import scala.util.Random._

val categories = List("drama", "musical", "thriller", "comedy", "horror", "action")
def category:String = shuffle(categories).head
val examples = List.fill(100)(Example(nextInt(2000), category, nextInt(2000).toLong, nextBoolean))
// Out:
// defined class Example
// import scala.util.Random._
// categories: List[String] = List(drama, musical, thriller, comedy, horror, action)
// category: String
// examples: List[Example] = List(Example(440,thriller,313,false), Example(1209,action,1288,false), Example(1066,horror,632,false), Example(1344,comedy,840,false), Example(1442,horror,413,false), Example(104,musical,648,false), Example(1453,musical,449,true), Example(509,thriller,1103,true), Example(1399,action,333,true), Example(363,drama,839,true), Example(188,drama,1770,true), Example(1566,thriller,135,true), Example(184,thriller,895,true), Example(1459,horror,1208,true), Example(714,thriller,1574,false), Example(1672,action,882,true), Example(108,comedy,1126,false), Example(1447,action,575,false), Example(1675,drama,1545,false), Example(62,...

// %% [markdown]
// The above cell doesn't plot anything since it terminates with a assignement.

// %%
examples
// Out:
// res16: List[Example] = List(Example(440,thriller,313,false), Example(1209,action,1288,false), Example(1066,horror,632,false), Example(1344,comedy,840,false), Example(1442,horror,413,false), Example(104,musical,648,false), Example(1453,musical,449,true), Example(509,thriller,1103,true), Example(1399,action,333,true), Example(363,drama,839,true), Example(188,drama,1770,true), Example(1566,thriller,135,true), Example(184,thriller,895,true), Example(1459,horror,1208,true), Example(714,thriller,1574,false), Example(1672,action,882,true), Example(108,comedy,1126,false), Example(1447,action,575,false), Example(1675,drama,1545,false), Example(62,comedy,1510,false), Example(229,action,1495,true), Example(1465,comedy,1808,true), Example(1428,comedy,680,true), Example(532,musical,1654,false), Exam...
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anona1fb7aa10a1c1370d330f337a61ab877&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;1266541621&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul1266541621"><li>
//               <a href="#tab1266541621-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab1266541621-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab1266541621"><div class="tab-pane" id="tab1266541621-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon350ae739be0ae9d16f3af2b27b05c400&quot;,&quot;dataInit&quot;:[{&quot;id&quot;:440,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:313,&quot;advanced&quot;:false},{&quot;id&quot;:1209,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:1288,&quot;advanced&quot;:false},{&quot;id&quot;:1066,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:632,&quot;advanced&quot;:false},{&quot;id&quot;:1344,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:840,&quot;advanced&quot;:false},{&quot;id&quot;:1442,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:413,&quot;advanced&quot;:false},{&quot;id&quot;:104,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:648,&quot;advanced&quot;:false},{&quot;id&quot;:1453,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:449,&quot;advanced&quot;:true},{&quot;id&quot;:509,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1103,&quot;advanced&quot;:true},{&quot;id&quot;:1399,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:333,&quot;advanced&quot;:true},{&quot;id&quot;:363,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:839,&quot;advanced&quot;:true},{&quot;id&quot;:188,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1770,&quot;advanced&quot;:true},{&quot;id&quot;:1566,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:135,&quot;advanced&quot;:true},{&quot;id&quot;:184,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:895,&quot;advanced&quot;:true},{&quot;id&quot;:1459,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:1208,&quot;advanced&quot;:true},{&quot;id&quot;:714,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1574,&quot;advanced&quot;:false},{&quot;id&quot;:1672,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:882,&quot;advanced&quot;:true},{&quot;id&quot;:108,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:1126,&quot;advanced&quot;:false},{&quot;id&quot;:1447,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:575,&quot;advanced&quot;:false},{&quot;id&quot;:1675,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1545,&quot;advanced&quot;:false},{&quot;id&quot;:62,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:1510,&quot;advanced&quot;:false},{&quot;id&quot;:229,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:1495,&quot;advanced&quot;:true},{&quot;id&quot;:1465,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:1808,&quot;advanced&quot;:true},{&quot;id&quot;:1428,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:680,&quot;advanced&quot;:true},{&quot;id&quot;:532,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:1654,&quot;advanced&quot;:false},{&quot;id&quot;:999,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:1461,&quot;advanced&quot;:true},{&quot;id&quot;:1533,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1120,&quot;advanced&quot;:false},{&quot;id&quot;:1193,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:70,&quot;advanced&quot;:true},{&quot;id&quot;:1775,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:566,&quot;advanced&quot;:true},{&quot;id&quot;:1495,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:596,&quot;advanced&quot;:true},{&quot;id&quot;:760,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1554,&quot;advanced&quot;:true},{&quot;id&quot;:1357,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:1335,&quot;advanced&quot;:false},{&quot;id&quot;:1731,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:1291,&quot;advanced&quot;:true},{&quot;id&quot;:840,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:1432,&quot;advanced&quot;:true},{&quot;id&quot;:1309,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:730,&quot;advanced&quot;:true},{&quot;id&quot;:181,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1823,&quot;advanced&quot;:false},{&quot ...

// %% [markdown]
// Now we have a `TableChart` and a `PivotChart` tabs for the data, which we can use to have a better feeling of the data.

// %% [markdown]
// We can of course create them ourselves:

// %%
TableChart(examples)
// Out:
// res18: notebook.front.widgets.charts.TableChart[List[Example]] = <TableChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon16d4e3f29e2ecfaa61d91a12b788f9b6&quot;,&quot;dataInit&quot;:[{&quot;id&quot;:440,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:313,&quot;advanced&quot;:false},{&quot;id&quot;:1209,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:1288,&quot;advanced&quot;:false},{&quot;id&quot;:1066,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:632,&quot;advanced&quot;:false},{&quot;id&quot;:1344,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:840,&quot;advanced&quot;:false},{&quot;id&quot;:1442,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:413,&quot;advanced&quot;:false},{&quot;id&quot;:104,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:648,&quot;advanced&quot;:false},{&quot;id&quot;:1453,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:449,&quot;advanced&quot;:true},{&quot;id&quot;:509,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1103,&quot;advanced&quot;:true},{&quot;id&quot;:1399,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:333,&quot;advanced&quot;:true},{&quot;id&quot;:363,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:839,&quot;advanced&quot;:true},{&quot;id&quot;:188,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1770,&quot;advanced&quot;:true},{&quot;id&quot;:1566,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:135,&quot;advanced&quot;:true},{&quot;id&quot;:184,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:895,&quot;advanced&quot;:true},{&quot;id&quot;:1459,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:1208,&quot;advanced&quot;:true},{&quot;id&quot;:714,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1574,&quot;advanced&quot;:false},{&quot;id&quot;:1672,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:882,&quot;advanced&quot;:true},{&quot;id&quot;:108,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:1126,&quot;advanced&quot;:false},{&quot;id&quot;:1447,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:575,&quot;advanced&quot;:false},{&quot;id&quot;:1675,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1545,&quot;advanced&quot;:false},{&quot;id&quot;:62,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:1510,&quot;advanced&quot;:false},{&quot;id&quot;:229,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:1495,&quot;advanced&quot;:true},{&quot;id&quot;:1465,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:1808,&quot;advanced&quot;:true},{&quot;id&quot;:1428,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:680,&quot;advanced&quot;:true},{&quot;id&quot;:532,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:1654,&quot;advanced&quot;:false},{&quot;id&quot;:999,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:1461,&quot;advanced&quot;:true},{&quot;id&quot;:1533,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1120,&quot;advanced&quot;:false},{&quot;id&quot;:1193,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:70,&quot;advanced&quot;:true},{&quot;id&quot;:1775,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:566,&quot;advanced&quot;:true},{&quot;id&quot;:1495,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:596,&quot;advanced&quot;:true},{&quot;id&quot;:760,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1554,&quot;advanced&quot;:true},{&quot;id&quot;:1357,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:1335,&quot;advanced&quot;:false},{&quot;id&quot;:1731,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:1291,&quot;advanced&quot;:true},{&quot;id&quot;:840,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:1432,&quot;advanced&quot;:true},{&quot;id&quot;:1309,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:730,&quot;advanced&quot;:true},{&quot;id&quot;:181,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1823,&quot;advanced&quot;:false},{&quot ...

// %% [markdown]
// ### Grouping plots

// %% [markdown]
// Among available charts, you have for instance the pretty common ones like:
// * `LineChart`
// * `ScatterChart`
// * `BarChart`
//
// Which accept at least two other parameters:
// * `fields`: the two field names to use to plot
// * `groupField`: the field used to group the data

// %%
val hitsPerCategory = spark.createDataset(examples).groupBy($"category").agg(sum("value") as "hits")
BarChart(hitsPerCategory, fields=Some(("category", "hits")))
// Out:
// hitsPerCategory: org.apache.spark.sql.DataFrame = [category: string, hits: bigint]
// res34: notebook.front.widgets.charts.BarChart[org.apache.spark.sql.DataFrame] = <BarChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon9ebbf4891740a0509bcedaa4d12c51c8&quot;,&quot;dataInit&quot;:[{&quot;category&quot;:&quot;action&quot;,&quot;hits&quot;:9032},{&quot;category&quot;:&quot;horror&quot;,&quot;hits&quot;:23149},{&quot;category&quot;:&quot;musical&quot;,&quot;hits&quot;:12632},{&quot;category&quot;:&quot;drama&quot;,&quot;hits&quot;:16703},{&quot;category&quot;:&quot;thriller&quot;,&quot;hits&quot;:23472},{&quot;category&quot;:&quot;comedy&quot;,&quot;hits&quot;:15870}],&quot;genId&quot;:&quot;1572616468&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/barChart'],
//       function(playground, _magicbarChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicbarChart,
//     "o": {"x":"category","y":"hits","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon2270346e687900ad3d8c8903a22f2ae9&quot;,&quot;initialValue&quot;:&quot;6&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon903e9233bda89593144266153f41e35e&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>

// %%
ScatterChart(examples, fields=Some(("id", "value")), groupField=Some("advanced"))
// Out:
// res22: notebook.front.widgets.charts.ScatterChart[List[Example]] = <ScatterChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anondbde4357e56625cfebf56d8a68a080e2&quot;,&quot;dataInit&quot;:[{&quot;id&quot;:440,&quot;value&quot;:313,&quot;advanced&quot;:false},{&quot;id&quot;:1209,&quot;value&quot;:1288,&quot;advanced&quot;:false},{&quot;id&quot;:1066,&quot;value&quot;:632,&quot;advanced&quot;:false},{&quot;id&quot;:1344,&quot;value&quot;:840,&quot;advanced&quot;:false},{&quot;id&quot;:1442,&quot;value&quot;:413,&quot;advanced&quot;:false},{&quot;id&quot;:104,&quot;value&quot;:648,&quot;advanced&quot;:false},{&quot;id&quot;:1453,&quot;value&quot;:449,&quot;advanced&quot;:true},{&quot;id&quot;:509,&quot;value&quot;:1103,&quot;advanced&quot;:true},{&quot;id&quot;:1399,&quot;value&quot;:333,&quot;advanced&quot;:true},{&quot;id&quot;:363,&quot;value&quot;:839,&quot;advanced&quot;:true},{&quot;id&quot;:188,&quot;value&quot;:1770,&quot;advanced&quot;:true},{&quot;id&quot;:1566,&quot;value&quot;:135,&quot;advanced&quot;:true},{&quot;id&quot;:184,&quot;value&quot;:895,&quot;advanced&quot;:true},{&quot;id&quot;:1459,&quot;value&quot;:1208,&quot;advanced&quot;:true},{&quot;id&quot;:714,&quot;value&quot;:1574,&quot;advanced&quot;:false},{&quot;id&quot;:1672,&quot;value&quot;:882,&quot;advanced&quot;:true},{&quot;id&quot;:108,&quot;value&quot;:1126,&quot;advanced&quot;:false},{&quot;id&quot;:1447,&quot;value&quot;:575,&quot;advanced&quot;:false},{&quot;id&quot;:1675,&quot;value&quot;:1545,&quot;advanced&quot;:false},{&quot;id&quot;:62,&quot;value&quot;:1510,&quot;advanced&quot;:false},{&quot;id&quot;:229,&quot;value&quot;:1495,&quot;advanced&quot;:true},{&quot;id&quot;:1465,&quot;value&quot;:1808,&quot;advanced&quot;:true},{&quot;id&quot;:1428,&quot;value&quot;:680,&quot;advanced&quot;:true},{&quot;id&quot;:532,&quot;value&quot;:1654,&quot;advanced&quot;:false},{&quot;id&quot;:999,&quot;value&quot;:1461,&quot;advanced&quot;:true},{&quot;id&quot;:1533,&quot;value&quot;:1120,&quot;advanced&quot;:false},{&quot;id&quot;:1193,&quot;value&quot;:70,&quot;advanced&quot;:true},{&quot;id&quot;:1775,&quot;value&quot;:566,&quot;advanced&quot;:true},{&quot;id&quot;:1495,&quot;value&quot;:596,&quot;advanced&quot;:true},{&quot;id&quot;:760,&quot;value&quot;:1554,&quot;advanced&quot;:true},{&quot;id&quot;:1357,&quot;value&quot;:1335,&quot;advanced&quot;:false},{&quot;id&quot;:1731,&quot;value&quot;:1291,&quot;advanced&quot;:true},{&quot;id&quot;:840,&quot;value&quot;:1432,&quot;advanced&quot;:true},{&quot;id&quot;:1309,&quot;value&quot;:730,&quot;advanced&quot;:true},{&quot;id&quot;:181,&quot;value&quot;:1823,&quot;advanced&quot;:false},{&quot;id&quot;:1923,&quot;value&quot;:1656,&quot;advanced&quot;:false},{&quot;id&quot;:1759,&quot;value&quot;:1525,&quot;advanced&quot;:false},{&quot;id&quot;:1841,&quot;value&quot;:541,&quot;advanced&quot;:false},{&quot;id&quot;:948,&quot;value&quot;:1811,&quot;advanced&quot;:false},{&quot;id&quot;:164,&quot;value&quot;:961,&quot;advanced&quot;:false},{&quot;id&quot;:1968,&quot;value&quot;:544,&quot;advanced&quot;:true},{&quot;id&quot;:824,&quot;value&quot;:157,&quot;advanced&quot;:true},{&quot;id&quot;:815,&quot;value&quot;:1526,&quot;advanced&quot;:false},{&quot;id&quot;:1465,&quot;value&quot;:762,&quot;advanced&quot;:true},{&quot;id&quot;:1102,&quot;value&quot;:1980,&quot;advanced&quot;:false},{&quot;id&quot;:853,&quot;value&quot;:880,&quot;advanced&quot;:true},{&quot;id&quot;:809,&quot;value&quot;:1116,&quot;advanced&quot;:true},{&quot;id&quot;:1447,&quot;value&quot;:648,&quot;advanced&quot;:false},{&quot;id&quot;:430,&quot;value&quot;:1886,&quot;advanced&quot;:false},{&quot;id&quot;:1197,&quot;value&quot;:1002,&quot;advanced&quot;:true},{&quot;id&quot;:231,&quot;value&quot;:1034,&quot;advanced&quot;:true},{&quot;id&quot;:1602,&quot;value&quot;:942,&quot;advanced&quot;:true},{&quot;id&quot;:451,&quot;value&quot;:473,&quot;advanced&quot;:true},{&quot;id&quot;:1107,&quot;value&quot;:509,&quot;advanced&quot;:true},{&quot;id&quot;:1741,&quot;value&quot;:1939,&quot;advanced&quot;:true},{&quot;i ...
//       function(playground, _magicscatterChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicscatterChart,
//     "o": {"x":"id","y":"value","width":600,"height":400,"g":"advanced"}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bin

// %%
BarChart(examples, fields=Some(("id", "value")), groupField=Some("category"))
// Out:
// res40: notebook.front.widgets.charts.BarChart[List[Example]] = <BarChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anond3d16a562d89ef9833f8b367aa99819f&quot;,&quot;dataInit&quot;:[{&quot;id&quot;:440,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:313},{&quot;id&quot;:1209,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:1288},{&quot;id&quot;:1066,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:632},{&quot;id&quot;:1344,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:840},{&quot;id&quot;:1442,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:413},{&quot;id&quot;:104,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:648},{&quot;id&quot;:1453,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:449},{&quot;id&quot;:509,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1103},{&quot;id&quot;:1399,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:333},{&quot;id&quot;:363,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:839},{&quot;id&quot;:188,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1770},{&quot;id&quot;:1566,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:135},{&quot;id&quot;:184,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:895},{&quot;id&quot;:1459,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:1208},{&quot;id&quot;:714,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1574},{&quot;id&quot;:1672,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:882},{&quot;id&quot;:108,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:1126},{&quot;id&quot;:1447,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:575},{&quot;id&quot;:1675,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1545},{&quot;id&quot;:62,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:1510},{&quot;id&quot;:229,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:1495},{&quot;id&quot;:1465,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:1808},{&quot;id&quot;:1428,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:680},{&quot;id&quot;:532,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:1654},{&quot;id&quot;:999,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:1461},{&quot;id&quot;:1533,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1120},{&quot;id&quot;:1193,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:70},{&quot;id&quot;:1775,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:566},{&quot;id&quot;:1495,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:596},{&quot;id&quot;:760,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1554},{&quot;id&quot;:1357,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:1335},{&quot;id&quot;:1731,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:1291},{&quot;id&quot;:840,&quot;category&quot;:&quot;musical&quot;,&quot;value&quot;:1432},{&quot;id&quot;:1309,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:730},{&quot;id&quot;:181,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:1823},{&quot;id&quot;:1923,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1656},{&quot;id&quot;:1759,&quot;category&quot;:&quot;horror&quot;,&quot;value&quot;:1525},{&quot;id&quot;:1841,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:541},{&quot;id&quot;:948,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1811},{&quot;id&quot;:164,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:961},{&quot;id&quot;:1968,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:544},{&quot;id&quot;:824,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:157},{&quot;id&quot;:815,&quot;category&quot;:&quot;thriller&quot;,&quot;value&quot;:1526},{&quot;id&quot;:1465,&quot;category&quot;:&quot;action&quot;,&quot;value&quot;:762},{&quot;id&quot;:1102,&quot;category&quot;:&quot;comedy&quot;,&quot;value&quot;:1980},{&quot;id&quot;:853,&quot;category&quot;:&quot;drama&quot;,&quot;value&quot;:880}, ...

// %% [markdown]
// ---
// ## Graphs

// %% [markdown]
// Graph is generally a common way to represent data where connections matter. Hence the Spark Notebook defines an API easing the definition of `Node` and `Edge`.
//
// * `Graph[T]`: abstract class defining a graph component with an id of type `T`, a value of type `Any` and a color
// * `Node[T]`: defines a node as a circle which can be specified a radius and its position ($x$, $y$) (initial or static if it's fixed)
// * `Edge[T]`: defines an edge using the ids of both ends

// %%
import scala.util.Random._
case class GraphExample(id:Int, cluster:Char, value:Long)
val clusters = ('A' to 'D').toList
val cluCol = clusters.zip(List("#000", "#478", "#127", "#984", "#F5A")).toMap
val gexamples = List.tabulate(10, 4)((i,j) => GraphExample(i*4+j, clusters(j), nextLong)).flatten

val nodes = gexamples.map(e => notebook.front.widgets.magic.Node(e.id, e, cluCol(e.cluster), 5))

val clustered = gexamples.groupBy(_.cluster).toList
val connectedClusters = clustered.flatMap { case (c, cl) => 
                                       for {
                                         a <- cl
                                         b <- cl if a != b
                                       } yield notebook.front.widgets.magic.Edge[Int](400+nextInt(400)+a.id+b.id, (a.id, b.id), "intra", "red")
                                     }
// Out:
// import scala.util.Random._
// defined class GraphExample
// clusters: List[Char] = List(A, B, C, D)
// cluCol: scala.collection.immutable.Map[Char,String] = Map(A -> #000, B -> #478, C -> #127, D -> #984)
// gexamples: List[GraphExample] = List(GraphExample(0,A,3912371022920081814), GraphExample(1,B,6412170878345702211), GraphExample(2,C,9204147210451903646), GraphExample(3,D,-5469523725007552212), GraphExample(4,A,1400166045456678603), GraphExample(5,B,117433689862059653), GraphExample(6,C,-2565296159209085778), GraphExample(7,D,-566587921581094860), GraphExample(8,A,6628864983314821656), GraphExample(9,B,-2115657522211612322), GraphExample(10,C,-2017054813330680589), GraphExample(11,D,5255636672555945057), GraphExample(12,A,855834809839472974), GraphExample(13,B,6543978274141533960), GraphExample...

// %%
val singleConnections = {
  val s = gexamples.take(4)
  
  
  for (a <- s; b <- s if a != b) 
    yield Edge(800+nextInt(400)+a.id+b.id, (a.id, b.id), "inter", "green")
}

val all = nodes ::: connectedClusters ::: singleConnections
// Out:
// singleConnections: List[notebook.front.widgets.magic.Edge[Int]] = List(Edge(938,(0,1),inter,green), Edge(819,(0,2),inter,green), Edge(1105,(0,3),inter,green), Edge(837,(1,0),inter,green), Edge(909,(1,2),inter,green), Edge(933,(1,3),inter,green), Edge(1056,(2,0),inter,green), Edge(822,(2,1),inter,green), Edge(810,(2,3),inter,green), Edge(1018,(3,0),inter,green), Edge(880,(3,1),inter,green), Edge(1187,(3,2),inter,green))
// all: List[Product with Serializable with notebook.front.widgets.magic.Graph[Int]] = List(Node(0,GraphExample(0,A,3912371022920081814),#000,5,None,false), Node(1,GraphExample(1,B,6412170878345702211),#478,5,None,false), Node(2,GraphExample(2,C,9204147210451903646),#127,5,None,false), Node(3,GraphExample(3,D,-5469523725007552212),#984,5,None,false), Node(4,GraphExample(4,A,...

// %%
GraphChart(all, maxPoints = 1000, sizes=(600, 600))
// Out:
// res46: notebook.front.widgets.charts.GraphChart[List[Product with Serializable with notebook.front.widgets.magic.Graph[Int]]] = <GraphChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon42b52300464915cc8b6b86383ff3bb62&quot;,&quot;dataInit&quot;:[{&quot;x&quot;:0.09690372047682505,&quot;y&quot;:0.5162827312260455,&quot;color&quot;:&quot;#000&quot;,&quot;cluster&quot;:&quot;A&quot;,&quot;id&quot;:0,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;0&quot;,&quot;value&quot;:3912371022920081814},{&quot;x&quot;:0.03857808547728436,&quot;y&quot;:0.5802354761761348,&quot;color&quot;:&quot;#478&quot;,&quot;cluster&quot;:&quot;B&quot;,&quot;id&quot;:1,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;1&quot;,&quot;value&quot;:6412170878345702211},{&quot;x&quot;:0.5415288311620555,&quot;y&quot;:0.9190070980991909,&quot;color&quot;:&quot;#127&quot;,&quot;cluster&quot;:&quot;C&quot;,&quot;id&quot;:2,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;2&quot;,&quot;value&quot;:9204147210451903646},{&quot;x&quot;:0.6910715826592565,&quot;y&quot;:0.9281616057283438,&quot;color&quot;:&quot;#984&quot;,&quot;cluster&quot;:&quot;D&quot;,&quot;id&quot;:3,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;3&quot;,&quot;value&quot;:-5469523725007552212},{&quot;x&quot;:0.046308596076130804,&quot;y&quot;:0.3984483699897704,&quot;color&quot;:&quot;#000&quot;,&quot;cluster&quot;:&quot;A&quot;,&quot;id&quot;:4,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;4&quot;,&quot;value&quot;:1400166045456678603},{&quot;x&quot;:0.17045472348553659,&quot;y&quot;:0.9261073523065614,&quot;color&quot;:&quot;#478&quot;,&quot;cluster&quot;:&quot;B&quot;,&quot;id&quot;:5,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;5&quot;,&quot;value&quot;:117433689862059653},{&quot;x&quot;:0.7324282345083561,&quot;y&quot;:0.7133001993162996,&quot;color&quot;:&quot;#127&quot;,&quot;cluster&quot;:&quot;C&quot;,&quot;id&quot;:6,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;6&quot;,&quot;value&quot;:-2565296159209085778},{&quot;x&quot;:0.01347121684887631,&quot;y&quot;:0.2405662516578546,&quot;color&quot;:&quot;#984&quot;,&quot;cluster&quot;:&quot;D&quot;,&quot;id&quot;:7,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;7&quot;,&quot;value&quot;:-566587921581094860},{&quot;x&quot;:0.5784249757029555,&quot;y&quot;:0.7137224788863676,&quot;color&quot;:&quot;#000&quot;,&quot;cluster&quot;:&quot;A&quot;,&quot;id&quot;:8,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;8&quot;,&quot;value&quot;:6628864983314821656},{&quot;x&quot;:0.5591713549087934,&quot;y&quot;:0.40190995808044805,&quot;color&quot;:&quot;#478&quot;,&quot;cluster&quot;:&quot;B&quot;,&quot;id&quot;:9,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;9&quot;,&quot;value&quot;:-2115657522211612322},{&quot;x&quot;:0.061918046837341145,&quot;y&quot;:0.9886044230976341,&quot;color&quot;:&quot;#127&quot;,&quot;cluster&quot;:&quot;C&quot;,&quot;id&quot;:10,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;10&quot;,&quot;value&quot;:-2017054813330680589},{&quot;x&quot;:0.8428375628233158,&quot;y&quot;:0.5535521697243737,&quot;color&quot;:&quot;#984&quot;,&quot;cluster&quot;:&quot;D&quot;,&quot;id&quot;:11,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;11&quot;,&quot;value&quot;:5255636672555945057},{&quot;x&quot;:0.618573156655101,&quot;y&quot;:0.4440841613566693,&quot;color&quot;:&quot;#000&quot;,&quot;cluster&quot;:&quot;A&quot;,&quot;id&quot;:12,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;12&quot;,&quot;value&quot;:855834809839472974},{&quot;x&quot;:0.2879342660762312,&quot;y&quot;:0.9355454930118909,&quot;color&quot;:&quot;#478&quot;,&quot;cluster&quot;:&quot;B&quot;,&quot;id&quot;:13,&quot;fixed&quot;:false,&quot;r&quot;:5,&quot;nodeId&quot;:&quot;13&quot;,&quot;value&quot;:6543978274141533960},{&quot;x&quot;:0.3654765059291485,&quot;y&quot;:0.5322270791156738,&quot;color&quot;:&quot;#127&quot;,&quot;cluster&quot;:&quot;C&quot;,&quot;id&quot;:14,&q ...

// %% [markdown]
// ---
// ## Geo charts

// %% [markdown]
// There are two types of geo charts:
// * `GeoPointsChart` for simple points lat long points
// * `GeoChart` for _GeoJSON_ or _opengis_ data

// %% [markdown]
// ### GeoPointsChart

// %% [markdown]
// Let's load some airports data with latitude and longitude coordinates

// %%
val root = "/home/maasg/projects/data-fellas/scala-for-data-science"
val airportsDF = sparkSession.read.json(s"$root/notebooks/airports.json")
airportsDF.cache
airportsDF
// Out:
// root: String = /home/maasg/projects/data-fellas/scala-for-data-science
// airportsDF: org.apache.spark.sql.DataFrame = [airport: string, city: string ... 5 more fields]
// res62: org.apache.spark.sql.DataFrame = [airport: string, city: string ... 5 more fields]
// <div class="df-canvas">
//       <script data-this="{&quot;dataId&quot;:&quot;anonf8d6955e59e407d0b9dc8f181891a480&quot;,&quot;partitionIndexId&quot;:&quot;anon56a889930ec127782afef45361268cc5&quot;,&quot;numPartitions&quot;:135,&quot;dfSchema&quot;:{&quot;type&quot;:&quot;struct&quot;,&quot;fields&quot;:[{&quot;name&quot;:&quot;airport&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;city&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;country&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;iata&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;lat&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;long&quot;,&quot;type&quot;:&quot;double&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;state&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}}]}}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/dataframe','../javascripts/notebook/consoleDir'],
//       function(dataframe, extension) {
//         dataframe.call(data, this, extension);
//       }
//     );/*]]>*/</script>
//       <link rel="stylesheet" href="/assets/stylesheets/ipython/css/dataframe.css" type="text/css"/>
//     </div>

// %%
val statsDF = airportsDF.groupBy("state").count.orderBy($"count".desc).limit(5)
// Out:
// statsDF: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [state: string, count: bigint]

// %% [markdown]
// Convert to Dataset (for the fun).

// %%
case class StateStat(state:String, count:Long)
// Out:
// defined class StateStat

// %%
statsDF.as[StateStat]
// Out:
// res66: org.apache.spark.sql.Dataset[StateStat] = [state: string, count: bigint]
// <div class="df-canvas">
//       <script data-this="{&quot;dataId&quot;:&quot;anonebb26e35b61452e485c409b14acde1af&quot;,&quot;partitionIndexId&quot;:&quot;anonf2cf28cafbef4ab2bb3870e14cddc6ce&quot;,&quot;numPartitions&quot;:1,&quot;dfSchema&quot;:{&quot;type&quot;:&quot;struct&quot;,&quot;fields&quot;:[{&quot;name&quot;:&quot;state&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;count&quot;,&quot;type&quot;:&quot;long&quot;,&quot;nullable&quot;:false,&quot;metadata&quot;:{}}]}}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/dataframe','../javascripts/notebook/consoleDir'],
//       function(dataframe, extension) {
//         dataframe.call(data, this, extension);
//       }
//     );/*]]>*/</script>
//       <link rel="stylesheet" href="/assets/stylesheets/ipython/css/dataframe.css" type="text/css"/>
//     </div>

// %% [markdown]
// Plot the dataframe with dedicated colors for each state

// %%
import org.apache.spark.sql.functions._
// Out:
// import org.apache.spark.sql.functions._

// %%
def forStates[A](xs:List[A]) = when($"state" === "AK", xs(0))
                               .when($"state" === "TX", xs(1))
                               .when($"state" === "CA", xs(2))
                               .when($"state" === "OK", xs(3))
                               .when($"state" === "OH", xs(4))
                               .otherwise(xs(5))
val airportsDFWithStyles = airportsDF.withColumn("r", forStates(List(10,9,8,7,6,1)))
                                     .withColumn("c", forStates(List("red","orange","blue","green","yellow","white")))
GeoPointsChart(airportsDFWithStyles, latLonFields=Some(("lat", "long")), rField = Some("r"), colorField = Some("c"))
// Out:
// forStates: [A](xs: List[A])org.apache.spark.sql.Column
// airportsDFWithStyles: org.apache.spark.sql.DataFrame = [airport: string, city: string ... 7 more fields]
// res69: notebook.front.widgets.charts.GeoPointsChart[org.apache.spark.sql.DataFrame] = <GeoPointsChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon2126c8a8941642ae6913ddd1edce792a&quot;,&quot;dataInit&quot;:[{&quot;long&quot;:-89.23450472,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:31.95376472},{&quot;long&quot;:-95.01792778,&quot;c&quot;:&quot;orange&quot;,&quot;r&quot;:9,&quot;lat&quot;:30.68586111},{&quot;long&quot;:-104.5698933,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:38.94574889},{&quot;long&quot;:-78.05208056,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:42.74134667},{&quot;long&quot;:-81.90594389,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:30.6880125},{&quot;long&quot;:-88.20111111,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:34.49166667},{&quot;long&quot;:-86.61145333,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:32.85048667},{&quot;long&quot;:-88.17786917,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:43.08751},{&quot;long&quot;:-80.64140639,&quot;c&quot;:&quot;yellow&quot;,&quot;r&quot;:6,&quot;lat&quot;:40.67331278},{&quot;long&quot;:-92.22696056,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:40.44725889},{&quot;long&quot;:-89.34285194,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:33.93011222},{&quot;long&quot;:-96.35089861,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:46.88384889},{&quot;long&quot;:-87.40109333,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:41.51961917},{&quot;long&quot;:-97.79696778,&quot;c&quot;:&quot;orange&quot;,&quot;r&quot;:9,&quot;lat&quot;:31.42127556},{&quot;long&quot;:-116.0050597,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:39.60416667},{&quot;long&quot;:-85.68003611,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:32.46047167},{&quot;long&quot;:-88.10124278,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:41.98934083},{&quot;long&quot;:-99.62087694,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:48.88434111},{&quot;long&quot;:-89.31256917,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:33.53456583},{&quot;long&quot;:-74.39191722,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:41.43156583},{&quot;long&quot;:-114.6580911,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:41.97602222},{&quot;long&quot;:-85.06433333,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:41.30716667},{&quot;long&quot;:-94.97174556,&quot;c&quot;:&quot;orange&quot;,&quot;r&quot;:9,&quot;lat&quot;:32.52883861},{&quot;long&quot;:-84.81143139,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:42.57450861},{&quot;long&quot;:-98.05033639,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:41.11668056},{&quot;long&quot;:-86.32822139,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:32.52943944},{&quot;long&quot;:-102.4063514,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:48.30079861},{&quot;long&quot;:-98.07978667,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:40.65138528},{&quot;long&quot;:-89.53007139,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:32.76124611},{&quot;long&quot;:-88.1274625,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:32.11931306},{&quot;long&quot;:-81.42777778,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:31.07447222},{&quot;long&quot;:-99.34038139,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:41.63695083},{&quot;long&quot;:-90.078145,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:33.99150222},{&quot;long&quot;:-77.00747583,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:38.86872333},{&quot;long&quot;:-85.80931806,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:35.98531194},{&quot;long&quot;:-87.08888306,&quot;c&quot;:&quot;white&quot;,&quot;r&quot;:1,&quot;lat&quot;:32.93679056} ...

// %% [markdown]
// ---
// ## GeoChart

// %% [markdown]
// Fetch some data on the web about parks and gardens

// %%
:sh wget http://data.cyc.opendata.arcgis.com/datasets/57fa576e5e8149b0b744f768e01e5ce1_0.geojson -O Parks_and_Gardens.geojson
// Out:
// --2016-10-03 20:23:24--  http://data.cyc.opendata.arcgis.com/datasets/57fa576e5e8149b0b744f768e01e5ce1_0.geojson
// Resolving data.cyc.opendata.arcgis.com (data.cyc.opendata.arcgis.com)... 52.71.54.58, 52.45.55.59
// Connecting to data.cyc.opendata.arcgis.com (data.cyc.opendata.arcgis.com)|52.71.54.58|:80... connected.
// HTTP request sent, awaiting response... 200 OK
// Length: unspecified [application/json]
// Saving to: ‘Parks_and_Gardens.geojson’
//
//      0K .......... .......... .......... .......... .......     149K=0,3s
//
// 2016-10-03 20:23:25 (149 KB/s) - ‘Parks_and_Gardens.geojson’ saved [48157]
//
//
// import sys.process._

// %% [markdown]
// Parse it as GeoJSON using provided `widgets.parseGeoJSON`

// %%
val geoJSONRepr = widgets.parseGeoJSON(scala.io.Source.fromFile("Parks_and_Gardens.geojson").getLines.mkString(""))
// Out:
// geoJSONRepr: org.wololo.geojson.GeoJSON = {"type":"FeatureCollection","features":[{"type":"Feature","geometry":{"type":"Polygon","coordinates":[[[-1.0586561844469051,53.95603309272234],[-1.05854399466353,53.95603230358679],[-1.0583760626436196,53.956040512630246],[-1.0581615796381862,53.9560514114069],[-1.0578934080246933,53.956069347443375],[-1.0575324639452257,53.95610587354096],[-1.0572491469247918,53.95613797567649],[-1.0569805467357019,53.956174865720776],[-1.0567978185678244,53.95620398210952],[-1.0566095948767782,53.956237188881765],[-1.0563513871859314,53.95628682886303],[-1.055997890932263,53.956366180073815],[-1.0557105892387082,53.95643544719732],[-1.0554643721163497,53.95651042797886],[-1.054881757917829,53.95669741874451],[-1.0548229580333113,53.95661375072628],[-1.05479500...

// %% [markdown]
// Fetch some more vectorial information of the same area.

// %%
:sh wget http://data.cyc.opendata.arcgis.com/datasets/9b212b7af275438ca9088ff868bda139_9.geojson -O airqual.geojson
// Out:
// --2016-10-03 20:23:27--  http://data.cyc.opendata.arcgis.com/datasets/9b212b7af275438ca9088ff868bda139_9.geojson
// Resolving data.cyc.opendata.arcgis.com (data.cyc.opendata.arcgis.com)... 52.71.54.58, 52.45.55.59
// Connecting to data.cyc.opendata.arcgis.com (data.cyc.opendata.arcgis.com)|52.71.54.58|:80... connected.
// HTTP request sent, awaiting response... 200 OK
// Length: unspecified [application/json]
// Saving to: ‘airqual.geojson’
//
//      0K .......... .......... .......... .......... ..........  118K
//     50K .......... .......... .......... .......... ..........  128K
//    100K .......... .......... .......... .......... .......... 1,10M
//    150K .......... .......... .......... .......... ..........  301K
//    200K .......... .......... .......... .......... ..........  248K
//    250K .......... .......... .......                          1,18M=1,3s
//
// 2016-10-03 20:23:28 (222 KB/s) - ‘airqual.geojson’ saved [284153]
//
//
// import sys.process._

// %% [markdown]
// And parse it...

// %%
val ng = widgets.parseGeoJSON(scala.io.Source.fromFile("airqual.geojson").getLines.mkString(""))
// Out:
// ng: org.wololo.geojson.GeoJSON = {"type":"FeatureCollection","features":[{"type":"Feature","geometry":{"type":"Polygon","coordinates":[[[-1.0993634390145945,53.94953467420566],[-1.0993632127017887,53.94953761160725],[-1.0993626606334983,53.949540533984006],[-1.0993617861083074,53.94954342967616],[-1.0993605924828298,53.949546284327965],[-1.09935908608327,53.94954908720113],[-1.0993572702275516,53.94955182573725],[-1.0993551558316914,53.94955448833359],[-1.0993529937136752,53.94955681981139],[-1.0980501642550011,53.95086841417698],[-1.098049919747874,53.95086865861476],[-1.0980472332209674,53.95087113533479],[-1.0980456879200573,53.95087241532106],[-1.0976919863244108,53.95115453694566],[-1.0976915894502317,53.95115485124434],[-1.0966111506989786,53.95200106454321],[-1.0966106547656387,5...

// %% [markdown]
// Create a `GeoChart` instance on `GeoJSON` representation of the first dataset.

// %%
val gc = GeoChart(Seq(geoJSONRepr), sizes=(800, 800))
gc
// Out:
// gc: notebook.front.widgets.charts.GeoChart[Seq[org.wololo.geojson.GeoJSON]] = <GeoChart widget>
// res77: notebook.front.widgets.charts.GeoChart[Seq[org.wololo.geojson.GeoJSON]] = <GeoChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonb86d65d4677d3ffc84993a6a9c64f688&quot;,&quot;dataInit&quot;:[{&quot;GeoJSON&quot;:{&quot;type&quot;:&quot;FeatureCollection&quot;,&quot;features&quot;:[{&quot;type&quot;:&quot;Feature&quot;,&quot;geometry&quot;:{&quot;type&quot;:&quot;Polygon&quot;,&quot;coordinates&quot;:[[[-1.0586561844469051,53.95603309272234],[-1.05854399466353,53.95603230358679],[-1.0583760626436196,53.956040512630246],[-1.0581615796381862,53.9560514114069],[-1.0578934080246933,53.956069347443375],[-1.0575324639452257,53.95610587354096],[-1.0572491469247918,53.95613797567649],[-1.0569805467357019,53.956174865720776],[-1.0567978185678244,53.95620398210952],[-1.0566095948767782,53.956237188881765],[-1.0563513871859314,53.95628682886303],[-1.055997890932263,53.956366180073815],[-1.0557105892387082,53.95643544719732],[-1.0554643721163497,53.95651042797886],[-1.054881757917829,53.95669741874451],[-1.0548229580333113,53.95661375072628],[-1.054795005629103,53.95658297941629],[-1.0546764051076285,53.956459933589066],[-1.0545849481152663,53.956481318490965],[-1.0545670056548235,53.95648018936191],[-1.0545259564990745,53.956483999203535],[-1.0545043289578508,53.95649020871827],[-1.054493484066902,53.956497491900805],[-1.0544860383067083,53.956510013194055],[-1.0544932426629519,53.956585907795876],[-1.0544762387184952,53.956671046689095],[-1.0544597989107292,53.95672563856191],[-1.0544186651060794,53.95680537621747],[-1.0541963996084833,53.95676570829095],[-1.0539332009276914,53.95648041270036],[-1.0539033500152164,53.95646130816395],[-1.0538857260862209,53.95645164462311],[-1.0538379124754842,53.95643230862352],[-1.0537987321301154,53.95642571048307],[-1.0537454512080322,53.95641477761591],[-1.0536883846549516,53.95641010542844],[-1.0536420982195036,53.95640659610402],[-1.053574210611199,53.95640812772132],[-1.0531418344883978,53.95642475984217],[-1.0527111723977223,53.95644347017403],[-1.0524074123686291,53.95645689004192],[-1.052278653036241,53.95646638713796],[-1.0521480147010425,53.95648117124391],[-1.0520851657455919,53.956493255099126],[-1.0520279592294253,53.956500262376],[-1.0518861840229554,53.956529604478355],[-1.0517945747265791,53.956552064631005],[-1.0517155071851898,53.95657561165385],[-1.0515842206767694,53.956618873948784],[-1.0514815046255497,53.956660116169786],[-1.0513932052237875,53.95669733801408],[-1.0512794271621158,53.95675538474916],[-1.0512107487543831,53.956791682788825],[-1.0511036462543475,53.95686559650597],[-1.050985630851925,53.95695523867823],[-1.0507783044818249,53.957121001799095],[-1.0505911783738884,53.95726589719393],[-1.0504257675723572,53.95739515059758],[-1.0503566581533386,53.957450404301696],[-1.050323976237927,53.95747854035585],[-1.0502907851996772,53.95752356539078],[-1.05006436721614,53.95758916668444],[-1.0493262881829584,53.95785289554279],[-1.0489879346730937,53.95797242167438],[-1.0489392551970114,53.95791938144767],[-1.048888130055408,53.957857875624626],[-1.0488282098654491,53.95777419492001],[-1.0487820327578334,53.95768855671117],[-1.048749594989631,53.95762306536862],[-1.0487429360435783,53.95760090827433],[-1.0487399633145458,53.957571411847205],[-1.0487319064072722,53.95753343010492],[-1.0487239696982853,53.957490146193756],[-1.0488262120764236,53.95746992967683],[-1.0489393019233149,53.95744243041009],[-1.0489601090019587,53.957439180464704],[-1.0489895676645848,53.95743123716153],[-1.0491857799593045,53.95736225292669],[-1.0495307074489049,53.957262816658016],[-1.0496915730117304,53.95717881587171],[-1.0497493590568028,53.957151867332364],[-1.0498049725178367,53.95713757034146],[-1.0498766204255963,53.957125467217445],[-1.0499267405552317,53.957120652104486],[-1.050012519658338,53.95711710655083],[-1.0501123551282299,53.957125264239835],[-1.0501533182203568,53.95713088912597],[-1.0502887824018765,53.95713609342218],[-1.0503303561797939,53.957131390649174],[-1.0503820316154946,53.95711894962723],[-1.0504341752037594,53.95710255838404],[-1.05049757215494 ...

// %% [markdown]
// We can now add the linear features into the same chart using the helpful function `addAndApply` which adds information to the existing chart.

// %%
gc.addAndApply(Seq(ng))

// %% [markdown]
// ---
// ## Fancy charts

// %% [markdown]
// ### Radar

// %% [markdown]
// Let's grab some data from http://www.basketball-reference.com/teams/SAS/2016.html (31st May 2016).

// %%
case class TeamMember(Player:String, Age:Int, FG_pc:Double, _3P_pc:Double, _2P_pc:Double, eFG_pc:Double, FT_pc:Double)
val team = 
      s"""
        1	Kawhi Leonard	24	72	72	2380	551	1090	.506	129	291	.443	422	799	.528	.565	292	334	.874	95	398	493	186	128	71	105	133	1523
        2	LaMarcus Aldridge	30	74	74	2261	536	1045	.513	0	16	.000	536	1029	.521	.513	259	302	.858	176	456	632	110	38	81	99	151	1331
        3	Danny Green	28	79	79	2062	211	561	.376	116	349	.332	95	212	.448	.480	34	46	.739	48	255	303	141	79	64	75	141	572
        4	Tony Parker	33	72	72	1980	350	710	.493	27	65	.415	323	645	.501	.512	130	171	.760	17	159	176	379	54	11	131	114	857
        5	Patrick Mills	27	81	3	1662	260	612	.425	123	320	.384	137	292	.469	.525	47	58	.810	27	131	158	226	59	6	76	102	690
        6	Tim Duncan	39	61	60	1536	215	441	.488	0	2	.000	215	439	.490	.488	92	131	.702	115	332	447	163	47	78	90	125	522
        7	David West	35	78	19	1404	244	448	.545	3	7	.429	241	441	.546	.548	63	80	.788	72	237	309	143	44	55	68	142	554
        8	Boris Diaw	33	76	4	1386	202	383	.527	25	69	.362	177	314	.564	.560	56	76	.737	58	175	233	176	26	21	97	102	485
        9	Kyle Anderson	22	78	11	1245	138	295	.468	12	37	.324	126	258	.488	.488	62	83	.747	25	219	244	123	60	29	59	97	350
        10	Manu Ginobili	38	58	0	1134	197	435	.453	70	179	.391	127	256	.496	.533	91	112	.813	26	120	146	177	66	11	99	99	555
        11	Jonathon Simmons	26	55	2	813	122	242	.504	18	47	.383	104	195	.533	.541	69	92	.750	16	80	96	58	24	5	53	103	331
        12	Boban Marjanovic	27	54	4	508	105	174	.603	0	0	.0	105	174	.603	.603	87	114	.763	73	121	194	21	12	23	29	54	297
        13	Rasual Butler	36	46	0	432	49	104	.471	15	49	.306	34	55	.618	.543	11	16	.688	3	53	56	24	13	23	8	11	124
        14	Kevin Martin	32	16	1	261	30	85	.353	11	33	.333	19	52	.365	.418	28	30	.933	4	25	29	12	9	2	13	15	99
        15	Ray McCallum	24	31	3	256	27	67	.403	5	16	.313	22	51	.431	.440	9	10	.900	6	25	31	33	5	4	11	14	68
        16	Matt Bonner	35	30	2	206	29	57	.509	15	34	.441	14	23	.609	.640	3	4	.750	3	24	27	9	6	1	3	16	76
        17	Andre Miller	39	13	4	181	23	48	.479	1	4	.250	22	44	.500	.490	9	13	.692	6	21	27	29	7	0	12	14	56
     """.trim.split("\n").map(s => s.trim.split("\t").drop(1).toList).map(x => (x.head, x(1).trim.toInt) → x.drop(2).filter(_.startsWith("."))
                                                                     .map(_.trim.toDouble * 100)).map { case ((p, a), stats)  =>
        TeamMember(p, a, stats(0), stats(1), stats(2), stats(3), stats(4))
      }
// Out:
// defined class TeamMember
// team: Array[TeamMember] = Array(TeamMember(Kawhi Leonard,24,50.6,44.3,52.800000000000004,56.49999999999999,87.4), TeamMember(LaMarcus Aldridge,30,51.300000000000004,0.0,52.1,51.300000000000004,85.8), TeamMember(Danny Green,28,37.6,33.2,44.800000000000004,48.0,73.9), TeamMember(Tony Parker,33,49.3,41.5,50.1,51.2,76.0), TeamMember(Patrick Mills,27,42.5,38.4,46.9,52.5,81.0), TeamMember(Tim Duncan,39,48.8,0.0,49.0,48.8,70.19999999999999), TeamMember(David West,35,54.50000000000001,42.9,54.6,54.800000000000004,78.8), TeamMember(Boris Diaw,33,52.7,36.199999999999996,56.39999999999999,56.00000000000001,73.7), TeamMember(Kyle Anderson,22,46.800000000000004,32.4,48.8,48.8,74.7), TeamMember(Manu Ginobili,38,45.300000000000004,39.1,49.6,53.300000000000004,81.3), TeamMember...

// %%
RadarChart(shuffle(team.toList).take(5), labelField=Some("Player"), sizes=(800, 600))
// Out:
// res82: notebook.front.widgets.charts.RadarChart[List[TeamMember]] = <RadarChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon725e6f2cb48d22ecc52c31392e77d347&quot;,&quot;dataInit&quot;:[{&quot;Player&quot;:&quot;Tim Duncan&quot;,&quot;FT_pc&quot;:70.19999999999999,&quot;_3P_pc&quot;:0.0,&quot;_2P_pc&quot;:49.0,&quot;Age&quot;:39,&quot;eFG_pc&quot;:48.8,&quot;FG_pc&quot;:48.8},{&quot;Player&quot;:&quot;Manu Ginobili&quot;,&quot;FT_pc&quot;:81.3,&quot;_3P_pc&quot;:39.1,&quot;_2P_pc&quot;:49.6,&quot;Age&quot;:38,&quot;eFG_pc&quot;:53.300000000000004,&quot;FG_pc&quot;:45.300000000000004},{&quot;Player&quot;:&quot;Jonathon Simmons&quot;,&quot;FT_pc&quot;:75.0,&quot;_3P_pc&quot;:38.3,&quot;_2P_pc&quot;:53.300000000000004,&quot;Age&quot;:26,&quot;eFG_pc&quot;:54.1,&quot;FG_pc&quot;:50.4},{&quot;Player&quot;:&quot;Kevin Martin&quot;,&quot;FT_pc&quot;:93.30000000000001,&quot;_3P_pc&quot;:33.300000000000004,&quot;_2P_pc&quot;:36.5,&quot;Age&quot;:32,&quot;eFG_pc&quot;:41.8,&quot;FG_pc&quot;:35.3},{&quot;Player&quot;:&quot;Kawhi Leonard&quot;,&quot;FT_pc&quot;:87.4,&quot;_3P_pc&quot;:44.3,&quot;_2P_pc&quot;:52.800000000000004,&quot;Age&quot;:24,&quot;eFG_pc&quot;:56.49999999999999,&quot;FG_pc&quot;:50.6}],&quot;genId&quot;:&quot;490659583&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/radarChart'],
//       function(playground, _magicradarChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicradarChart,
//     "o": {"classCol":"Player","axisCols":["Age","FG_pc","_3P_pc","_2P_pc","eFG_pc","FT_pc"],"width":800,"height":600}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon73e3709324a72b3e91420cf84354be9f&quot;,&quot;initialValue&quot;:&quot;5&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonf11d0587b254f82a5f63b74975272179&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>

// %% [markdown]
// ### Pivot

// %%
PivotChart(team)
// Out:
// res84: notebook.front.widgets.charts.PivotChart[Array[TeamMember]] = <PivotChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonbb303197178f7c76368bd0e582ce879e&quot;,&quot;dataInit&quot;:[{&quot;Player&quot;:&quot;Kawhi Leonard&quot;,&quot;FT_pc&quot;:87.4,&quot;_3P_pc&quot;:44.3,&quot;_2P_pc&quot;:52.800000000000004,&quot;Age&quot;:24,&quot;eFG_pc&quot;:56.49999999999999,&quot;FG_pc&quot;:50.6},{&quot;Player&quot;:&quot;LaMarcus Aldridge&quot;,&quot;FT_pc&quot;:85.8,&quot;_3P_pc&quot;:0.0,&quot;_2P_pc&quot;:52.1,&quot;Age&quot;:30,&quot;eFG_pc&quot;:51.300000000000004,&quot;FG_pc&quot;:51.300000000000004},{&quot;Player&quot;:&quot;Danny Green&quot;,&quot;FT_pc&quot;:73.9,&quot;_3P_pc&quot;:33.2,&quot;_2P_pc&quot;:44.800000000000004,&quot;Age&quot;:28,&quot;eFG_pc&quot;:48.0,&quot;FG_pc&quot;:37.6},{&quot;Player&quot;:&quot;Tony Parker&quot;,&quot;FT_pc&quot;:76.0,&quot;_3P_pc&quot;:41.5,&quot;_2P_pc&quot;:50.1,&quot;Age&quot;:33,&quot;eFG_pc&quot;:51.2,&quot;FG_pc&quot;:49.3},{&quot;Player&quot;:&quot;Patrick Mills&quot;,&quot;FT_pc&quot;:81.0,&quot;_3P_pc&quot;:38.4,&quot;_2P_pc&quot;:46.9,&quot;Age&quot;:27,&quot;eFG_pc&quot;:52.5,&quot;FG_pc&quot;:42.5},{&quot;Player&quot;:&quot;Tim Duncan&quot;,&quot;FT_pc&quot;:70.19999999999999,&quot;_3P_pc&quot;:0.0,&quot;_2P_pc&quot;:49.0,&quot;Age&quot;:39,&quot;eFG_pc&quot;:48.8,&quot;FG_pc&quot;:48.8},{&quot;Player&quot;:&quot;David West&quot;,&quot;FT_pc&quot;:78.8,&quot;_3P_pc&quot;:42.9,&quot;_2P_pc&quot;:54.6,&quot;Age&quot;:35,&quot;eFG_pc&quot;:54.800000000000004,&quot;FG_pc&quot;:54.50000000000001},{&quot;Player&quot;:&quot;Boris Diaw&quot;,&quot;FT_pc&quot;:73.7,&quot;_3P_pc&quot;:36.199999999999996,&quot;_2P_pc&quot;:56.39999999999999,&quot;Age&quot;:33,&quot;eFG_pc&quot;:56.00000000000001,&quot;FG_pc&quot;:52.7},{&quot;Player&quot;:&quot;Kyle Anderson&quot;,&quot;FT_pc&quot;:74.7,&quot;_3P_pc&quot;:32.4,&quot;_2P_pc&quot;:48.8,&quot;Age&quot;:22,&quot;eFG_pc&quot;:48.8,&quot;FG_pc&quot;:46.800000000000004},{&quot;Player&quot;:&quot;Manu Ginobili&quot;,&quot;FT_pc&quot;:81.3,&quot;_3P_pc&quot;:39.1,&quot;_2P_pc&quot;:49.6,&quot;Age&quot;:38,&quot;eFG_pc&quot;:53.300000000000004,&quot;FG_pc&quot;:45.300000000000004},{&quot;Player&quot;:&quot;Jonathon Simmons&quot;,&quot;FT_pc&quot;:75.0,&quot;_3P_pc&quot;:38.3,&quot;_2P_pc&quot;:53.300000000000004,&quot;Age&quot;:26,&quot;eFG_pc&quot;:54.1,&quot;FG_pc&quot;:50.4},{&quot;Player&quot;:&quot;Boban Marjanovic&quot;,&quot;FT_pc&quot;:76.3,&quot;_3P_pc&quot;:0.0,&quot;_2P_pc&quot;:60.3,&quot;Age&quot;:27,&quot;eFG_pc&quot;:60.3,&quot;FG_pc&quot;:60.3},{&quot;Player&quot;:&quot;Rasual Butler&quot;,&quot;FT_pc&quot;:68.8,&quot;_3P_pc&quot;:30.599999999999998,&quot;_2P_pc&quot;:61.8,&quot;Age&quot;:36,&quot;eFG_pc&quot;:54.300000000000004,&quot;FG_pc&quot;:47.099999999999994},{&quot;Player&quot;:&quot;Kevin Martin&quot;,&quot;FT_pc&quot;:93.30000000000001,&quot;_3P_pc&quot;:33.300000000000004,&quot;_2P_pc&quot;:36.5,&quot;Age&quot;:32,&quot;eFG_pc&quot;:41.8,&quot;FG_pc&quot;:35.3},{&quot;Player&quot;:&quot;Ray McCallum&quot;,&quot;FT_pc&quot;:90.0,&quot;_3P_pc&quot;:31.3,&quot;_2P_pc&quot;:43.1,&quot;Age&quot;:24,&quot;eFG_pc&quot;:44.0,&quot;FG_pc&quot;:40.300000000000004},{&quot;Player&quot;:&quot;Matt Bonner&quot;,&quot;FT_pc&quot;:75.0,&quot;_3P_pc&quot;:44.1,&quot;_2P_pc&quot;:60.9,&quot;Age&quot;:35,&quot;eFG_pc&quot;:64.0,&quot;FG_pc&quot;:50.9},{&quot;Player&quot;:&quot;Andre Miller&quot;,&quot;FT_pc&quot;:69.19999999999999,&quot;_3P_pc&quot;:25.0,&quot;_2P_pc&quot;:50.0,&quot;Age&quot;:39,&quot;eFG_pc&quot;:49.0,&quot;FG_pc&quot;:47.9}],&quot;genId&quot;:&quot;1634623744&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anond9bcea395dec53eff2ba4b0b68e0b971&quot;,&quot;initialValue&quot;:&quot;17&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon0122d2ab7ef5549333dc174e46c8bfaf&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>

// %% [markdown]
// ### Parallel coordinates

// %%
ParallelCoordChart(team, sizes=(800, 500))
// Out:
// res86: notebook.front.widgets.charts.ParallelCoordChart[Array[TeamMember]] = <ParallelCoordChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon5a3ef3f35b18541860699c3988b07fe0&quot;,&quot;dataInit&quot;:[{&quot;Player&quot;:&quot;Kawhi Leonard&quot;,&quot;FT_pc&quot;:87.4,&quot;_3P_pc&quot;:44.3,&quot;_2P_pc&quot;:52.800000000000004,&quot;Age&quot;:24,&quot;eFG_pc&quot;:56.49999999999999,&quot;FG_pc&quot;:50.6},{&quot;Player&quot;:&quot;LaMarcus Aldridge&quot;,&quot;FT_pc&quot;:85.8,&quot;_3P_pc&quot;:0.0,&quot;_2P_pc&quot;:52.1,&quot;Age&quot;:30,&quot;eFG_pc&quot;:51.300000000000004,&quot;FG_pc&quot;:51.300000000000004},{&quot;Player&quot;:&quot;Danny Green&quot;,&quot;FT_pc&quot;:73.9,&quot;_3P_pc&quot;:33.2,&quot;_2P_pc&quot;:44.800000000000004,&quot;Age&quot;:28,&quot;eFG_pc&quot;:48.0,&quot;FG_pc&quot;:37.6},{&quot;Player&quot;:&quot;Tony Parker&quot;,&quot;FT_pc&quot;:76.0,&quot;_3P_pc&quot;:41.5,&quot;_2P_pc&quot;:50.1,&quot;Age&quot;:33,&quot;eFG_pc&quot;:51.2,&quot;FG_pc&quot;:49.3},{&quot;Player&quot;:&quot;Patrick Mills&quot;,&quot;FT_pc&quot;:81.0,&quot;_3P_pc&quot;:38.4,&quot;_2P_pc&quot;:46.9,&quot;Age&quot;:27,&quot;eFG_pc&quot;:52.5,&quot;FG_pc&quot;:42.5},{&quot;Player&quot;:&quot;Tim Duncan&quot;,&quot;FT_pc&quot;:70.19999999999999,&quot;_3P_pc&quot;:0.0,&quot;_2P_pc&quot;:49.0,&quot;Age&quot;:39,&quot;eFG_pc&quot;:48.8,&quot;FG_pc&quot;:48.8},{&quot;Player&quot;:&quot;David West&quot;,&quot;FT_pc&quot;:78.8,&quot;_3P_pc&quot;:42.9,&quot;_2P_pc&quot;:54.6,&quot;Age&quot;:35,&quot;eFG_pc&quot;:54.800000000000004,&quot;FG_pc&quot;:54.50000000000001},{&quot;Player&quot;:&quot;Boris Diaw&quot;,&quot;FT_pc&quot;:73.7,&quot;_3P_pc&quot;:36.199999999999996,&quot;_2P_pc&quot;:56.39999999999999,&quot;Age&quot;:33,&quot;eFG_pc&quot;:56.00000000000001,&quot;FG_pc&quot;:52.7},{&quot;Player&quot;:&quot;Kyle Anderson&quot;,&quot;FT_pc&quot;:74.7,&quot;_3P_pc&quot;:32.4,&quot;_2P_pc&quot;:48.8,&quot;Age&quot;:22,&quot;eFG_pc&quot;:48.8,&quot;FG_pc&quot;:46.800000000000004},{&quot;Player&quot;:&quot;Manu Ginobili&quot;,&quot;FT_pc&quot;:81.3,&quot;_3P_pc&quot;:39.1,&quot;_2P_pc&quot;:49.6,&quot;Age&quot;:38,&quot;eFG_pc&quot;:53.300000000000004,&quot;FG_pc&quot;:45.300000000000004},{&quot;Player&quot;:&quot;Jonathon Simmons&quot;,&quot;FT_pc&quot;:75.0,&quot;_3P_pc&quot;:38.3,&quot;_2P_pc&quot;:53.300000000000004,&quot;Age&quot;:26,&quot;eFG_pc&quot;:54.1,&quot;FG_pc&quot;:50.4},{&quot;Player&quot;:&quot;Boban Marjanovic&quot;,&quot;FT_pc&quot;:76.3,&quot;_3P_pc&quot;:0.0,&quot;_2P_pc&quot;:60.3,&quot;Age&quot;:27,&quot;eFG_pc&quot;:60.3,&quot;FG_pc&quot;:60.3},{&quot;Player&quot;:&quot;Rasual Butler&quot;,&quot;FT_pc&quot;:68.8,&quot;_3P_pc&quot;:30.599999999999998,&quot;_2P_pc&quot;:61.8,&quot;Age&quot;:36,&quot;eFG_pc&quot;:54.300000000000004,&quot;FG_pc&quot;:47.099999999999994},{&quot;Player&quot;:&quot;Kevin Martin&quot;,&quot;FT_pc&quot;:93.30000000000001,&quot;_3P_pc&quot;:33.300000000000004,&quot;_2P_pc&quot;:36.5,&quot;Age&quot;:32,&quot;eFG_pc&quot;:41.8,&quot;FG_pc&quot;:35.3},{&quot;Player&quot;:&quot;Ray McCallum&quot;,&quot;FT_pc&quot;:90.0,&quot;_3P_pc&quot;:31.3,&quot;_2P_pc&quot;:43.1,&quot;Age&quot;:24,&quot;eFG_pc&quot;:44.0,&quot;FG_pc&quot;:40.300000000000004},{&quot;Player&quot;:&quot;Matt Bonner&quot;,&quot;FT_pc&quot;:75.0,&quot;_3P_pc&quot;:44.1,&quot;_2P_pc&quot;:60.9,&quot;Age&quot;:35,&quot;eFG_pc&quot;:64.0,&quot;FG_pc&quot;:50.9},{&quot;Player&quot;:&quot;Andre Miller&quot;,&quot;FT_pc&quot;:69.19999999999999,&quot;_3P_pc&quot;:25.0,&quot;_2P_pc&quot;:50.0,&quot;Age&quot;:39,&quot;eFG_pc&quot;:49.0,&quot;FG_pc&quot;:47.9}],&quot;genId&quot;:&quot;1406787608&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pcChart'],
//       function(playground, _magicpcChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpcChart,
//     "o": {"headers":["Player","Age","FG_pc","_3P_pc","_2P_pc","eFG_pc","FT_pc"],"width":800,"height":500}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonefa297f46139a57410a4df407be017be&quot;,&quot;initialValue&quot;:&quot;17&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonb80d4f2424275cddec62fc377115e83b&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>

// %% [markdown]
// ### Timeseries

// %%
:sh wget http://www.ncdc.noaa.gov/cag/time-series/global/globe/land_ocean/p12/12/1880-2015.csv -O /tmp/1880-2015.csv
// Out:
// --2016-10-03 20:23:34--  http://www.ncdc.noaa.gov/cag/time-series/global/globe/land_ocean/p12/12/1880-2015.csv
// Resolving www.ncdc.noaa.gov (www.ncdc.noaa.gov)... 205.167.25.171, 205.167.25.172, 2610:20:8040:2::171, ...
// Connecting to www.ncdc.noaa.gov (www.ncdc.noaa.gov)|205.167.25.171|:80... connected.
// HTTP request sent, awaiting response... 200 OK
// Length: unspecified [text/plain]
// Saving to: ‘/tmp/1880-2015.csv’
//
//      0K .......... .......... ...                               124K=0,2s
//
// 2016-10-03 20:23:35 (124 KB/s) - ‘/tmp/1880-2015.csv’ saved [23819]
//
//
// import sys.process._

// %%
import java.util.Calendar
import java.util.Calendar._
val cal = Calendar.getInstance
cal.set(DAY_OF_MONTH, 0)
cal.set(HOUR, 0)
cal.set(MINUTE, 0)
cal.set(SECOND, 0)
cal.set(MILLISECOND, 0)
val ts = scala.io.Source.fromFile(new File("/tmp/1880-2015.csv")).getLines.drop(4)
                .map(_.split(",").toList.map(_.trim))
                .map{case List(y,c) => (y.take(4).toInt, y.drop(4).take(2).dropWhile(_ == '0').toInt-1, c.toDouble)}
                .map{ case (y, m, c) => 
                  cal.set(YEAR, y)
                  cal.set(MONTH, m)
                  cal.getTime → c
                }.toList
// Out:
// import java.util.Calendar
// import java.util.Calendar._
// cal: java.util.Calendar = java.util.GregorianCalendar[time=1449054000000,areFieldsSet=true,areAllFieldsSet=false,lenient=true,zone=sun.util.calendar.ZoneInfo[id="Europe/Brussels",offset=3600000,dstSavings=3600000,useDaylight=true,transitions=184,lastRule=java.util.SimpleTimeZone[id=Europe/Brussels,offset=3600000,dstSavings=3600000,useDaylight=true,startYear=0,startMode=2,startMonth=2,startDay=-1,startDayOfWeek=1,startTime=3600000,startTimeMode=2,endMode=2,endMonth=9,endDay=-1,endDayOfWeek=1,endTime=3600000,endTimeMode=2]],firstDayOfWeek=1,minimalDaysInFirstWeek=1,ERA=1,YEAR=2015,MONTH=11,WEEK_OF_YEAR=49,WEEK_OF_MONTH=1,DAY_OF_MONTH=2,DAY_OF_YEAR=336,DAY_OF_WEEK=4,DAY_OF_WEEK_IN_MONTH=1,AM_PM=1,HOUR=0,HOUR_OF_DAY=12,MINUTE=0,SECOND=0,...

// %%
val tc = TimeseriesChart(ts)
// Out:
// tc: notebook.front.widgets.charts.TimeseriesChart[List[(java.util.Date, Double)]] = <TimeseriesChart widget>

// %%
tc
// Out:
// res92: notebook.front.widgets.charts.TimeseriesChart[List[(java.util.Date, Double)]] = <TimeseriesChart widget>
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonfb303eb270ab43c9ff24f2f31ef04c72&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:-2840187600000,&quot;_2&quot;:-0.003},{&quot;_1&quot;:-2834830800000,&quot;_2&quot;:-0.1286},{&quot;_1&quot;:-2834830800000,&quot;_2&quot;:-0.1398},{&quot;_1&quot;:-2832152400000,&quot;_2&quot;:-0.0552},{&quot;_1&quot;:-2829560400000,&quot;_2&quot;:-0.0775},{&quot;_1&quot;:-2826882000000,&quot;_2&quot;:-0.1718},{&quot;_1&quot;:-2824290000000,&quot;_2&quot;:-0.1545},{&quot;_1&quot;:-2821611600000,&quot;_2&quot;:-0.0772},{&quot;_1&quot;:-2818933200000,&quot;_2&quot;:-0.0851},{&quot;_1&quot;:-2816341200000,&quot;_2&quot;:-0.1827},{&quot;_1&quot;:-2813662800000,&quot;_2&quot;:-0.2709},{&quot;_1&quot;:-2811070800000,&quot;_2&quot;:-0.0823},{&quot;_1&quot;:-2808392400000,&quot;_2&quot;:-0.0239},{&quot;_1&quot;:-2805714000000,&quot;_2&quot;:-0.0327},{&quot;_1&quot;:-2803294800000,&quot;_2&quot;:0.03},{&quot;_1&quot;:-2800616400000,&quot;_2&quot;:0.0696},{&quot;_1&quot;:-2798024400000,&quot;_2&quot;:0.0225},{&quot;_1&quot;:-2795346000000,&quot;_2&quot;:-0.0968},{&quot;_1&quot;:-2792754000000,&quot;_2&quot;:-0.0401},{&quot;_1&quot;:-2790075600000,&quot;_2&quot;:-0.06},{&quot;_1&quot;:-2787397200000,&quot;_2&quot;:-0.1876},{&quot;_1&quot;:-2784805200000,&quot;_2&quot;:-0.2255},{&quot;_1&quot;:-2782126800000,&quot;_2&quot;:-0.2266},{&quot;_1&quot;:-2779534800000,&quot;_2&quot;:-0.0489},{&quot;_1&quot;:-2776856400000,&quot;_2&quot;:0.0855},{&quot;_1&quot;:-2774178000000,&quot;_2&quot;:0.0302},{&quot;_1&quot;:-2771758800000,&quot;_2&quot;:0.0682},{&quot;_1&quot;:-2769080400000,&quot;_2&quot;:-0.1289},{&quot;_1&quot;:-2766488400000,&quot;_2&quot;:-0.1516},{&quot;_1&quot;:-2763810000000,&quot;_2&quot;:-0.1458},{&quot;_1&quot;:-2761218000000,&quot;_2&quot;:-0.0707},{&quot;_1&quot;:-2758539600000,&quot;_2&quot;:-0.0079},{&quot;_1&quot;:-2755861200000,&quot;_2&quot;:0.0019},{&quot;_1&quot;:-2753269200000,&quot;_2&quot;:-0.214},{&quot;_1&quot;:-2750590800000,&quot;_2&quot;:-0.1315},{&quot;_1&quot;:-2747998800000,&quot;_2&quot;:-0.1785},{&quot;_1&quot;:-2745320400000,&quot;_2&quot;:-0.2735},{&quot;_1&quot;:-2742642000000,&quot;_2&quot;:-0.2987},{&quot;_1&quot;:-2740222800000,&quot;_2&quot;:-0.1369},{&quot;_1&quot;:-2737544400000,&quot;_2&quot;:-0.1791},{&quot;_1&quot;:-2734952400000,&quot;_2&quot;:-0.1469},{&quot;_1&quot;:-2732274000000,&quot;_2&quot;:-0.012},{&quot;_1&quot;:-2729682000000,&quot;_2&quot;:-0.0878},{&quot;_1&quot;:-2727003600000,&quot;_2&quot;:-0.0542},{&quot;_1&quot;:-2724325200000,&quot;_2&quot;:-0.1519},{&quot;_1&quot;:-2721733200000,&quot;_2&quot;:-0.1683},{&quot;_1&quot;:-2719054800000,&quot;_2&quot;:-0.1745},{&quot;_1&quot;:-2716462800000,&quot;_2&quot;:-0.0802},{&quot;_1&quot;:-2713784400000,&quot;_2&quot;:-0.1926},{&quot;_1&quot;:-2711106000000,&quot;_2&quot;:-0.1528},{&quot;_1&quot;:-2708600400000,&quot;_2&quot;:-0.2132},{&quot;_1&quot;:-2705922000000,&quot;_2&quot;:-0.1913},{&quot;_1&quot;:-2703330000000,&quot;_2&quot;:-0.1362},{&quot;_1&quot;:-2700651600000,&quot;_2&quot;:-0.2052},{&quot;_1&quot;:-2698059600000,&quot;_2&quot;:-0.3101},{&quot;_1&quot;:-2695381200000,&quot;_2&quot;:-0.2788},{&quot;_1&quot;:-2692702800000,&quot;_2&quot;:-0.2346},{&quot;_1&quot;:-2690110800000,&quot;_2&quot;:-0.1841},{&quot;_1&quot;:-2687432400000,&quot;_2&quot;:-0.2788},{&quot;_1&quot;:-2684840400000,&quot;_2&quot;:-0.1579},{&quot;_1&quot;:-2682162000000,&quot;_2&quot;:-0.438},{&quot;_1&quot;:-2679483600000,&quot;_2&quot;:-0.2701},{&quot;_1&quot;:-2677064400000,&quot;_2&quot;:-0.1583},{&quot;_1&quot;:-2674386000000,&quot;_2&quot;:-0.2679},{&quot;_1&quot;:-2671794000000,&quot;_2&quot;:-0.2941},{&quot;_1&quot;:-2669115600000,&quot;_2&quot;:-0.3207},{&quot;_1&quot;:-2666523600000,&quot;_2&quot;:-0.2504},{&quot;_1&quot;:-2663845200000,&quot;_2&quot;:-0.2529},{&quot;_1&quot;:-2661166800000,&quot;_2&quot;:-0.2082},{&quot;_1&quot;:-2658574800000,&quot;_2&quot;:-0.1391},{&quot;_1&quot;:-2655896400000,&quot;_2&quot;:-0. ...

// %%
val pairs = Seq((49,39,"foo"),(49,22,"foo"),(33,0,"bum"))
// Out:
// pairs: Seq[(Int, Int, String)] = List((49,39,foo), (49,22,foo), (33,0,bum))

// %% [markdown]
// ---
// ## Everything is Dynamic and Reactive

// %% [markdown]
// Since data can come live in a system or you want to log vizualy some events or perhaps you need to have two visual components to interact... what you don't want to do is to write the html, js, server code and who knows what else you'll need to master...
//
// For that, the spark notebook comes with dynamicity of charts and most (if not all) components can be listened and react to events.

// %% [markdown]
// ### Dynamic Line Chart

// %%
val tsH :: tsS = ts.sliding(100, 100).toList
val dynTC = TimeseriesChart(tsH, maxPoints = ts.size)
dynTC
// Out:
// tsH: List[(java.util.Date, Double)] = List((Wed Dec 31 12:00:00 CET 1879,-0.003), (Tue Mar 02 12:00:00 CET 1880,-0.1286), (Tue Mar 02 12:00:00 CET 1880,-0.1398), (Fri Apr 02 12:00:00 CET 1880,-0.0552), (Sun May 02 12:00:00 CET 1880,-0.0775), (Wed Jun 02 12:00:00 CET 1880,-0.1718), (Fri Jul 02 12:00:00 CET 1880,-0.1545), (Mon Aug 02 12:00:00 CET 1880,-0.0772), (Thu Sep 02 12:00:00 CET 1880,-0.0851), (Sat Oct 02 12:00:00 CET 1880,-0.1827), (Tue Nov 02 12:00:00 CET 1880,-0.2709), (Thu Dec 02 12:00:00 CET 1880,-0.0823), (Sun Jan 02 12:00:00 CET 1881,-0.0239), (Wed Feb 02 12:00:00 CET 1881,-0.0327), (Wed Mar 02 12:00:00 CET 1881,0.03), (Sat Apr 02 12:00:00 CET 1881,0.0696), (Mon May 02 12:00:00 CET 1881,0.0225), (Thu Jun 02 12:00:00 CET 1881,-0.0968), (Sat Jul 02 12:00:00 CET 1881,-0.0401), ...
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon64a4407edd3284a989316f9398d835e4&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:-2840187600000,&quot;_2&quot;:-0.003},{&quot;_1&quot;:-2834830800000,&quot;_2&quot;:-0.1286},{&quot;_1&quot;:-2834830800000,&quot;_2&quot;:-0.1398},{&quot;_1&quot;:-2832152400000,&quot;_2&quot;:-0.0552},{&quot;_1&quot;:-2829560400000,&quot;_2&quot;:-0.0775},{&quot;_1&quot;:-2826882000000,&quot;_2&quot;:-0.1718},{&quot;_1&quot;:-2824290000000,&quot;_2&quot;:-0.1545},{&quot;_1&quot;:-2821611600000,&quot;_2&quot;:-0.0772},{&quot;_1&quot;:-2818933200000,&quot;_2&quot;:-0.0851},{&quot;_1&quot;:-2816341200000,&quot;_2&quot;:-0.1827},{&quot;_1&quot;:-2813662800000,&quot;_2&quot;:-0.2709},{&quot;_1&quot;:-2811070800000,&quot;_2&quot;:-0.0823},{&quot;_1&quot;:-2808392400000,&quot;_2&quot;:-0.0239},{&quot;_1&quot;:-2805714000000,&quot;_2&quot;:-0.0327},{&quot;_1&quot;:-2803294800000,&quot;_2&quot;:0.03},{&quot;_1&quot;:-2800616400000,&quot;_2&quot;:0.0696},{&quot;_1&quot;:-2798024400000,&quot;_2&quot;:0.0225},{&quot;_1&quot;:-2795346000000,&quot;_2&quot;:-0.0968},{&quot;_1&quot;:-2792754000000,&quot;_2&quot;:-0.0401},{&quot;_1&quot;:-2790075600000,&quot;_2&quot;:-0.06},{&quot;_1&quot;:-2787397200000,&quot;_2&quot;:-0.1876},{&quot;_1&quot;:-2784805200000,&quot;_2&quot;:-0.2255},{&quot;_1&quot;:-2782126800000,&quot;_2&quot;:-0.2266},{&quot;_1&quot;:-2779534800000,&quot;_2&quot;:-0.0489},{&quot;_1&quot;:-2776856400000,&quot;_2&quot;:0.0855},{&quot;_1&quot;:-2774178000000,&quot;_2&quot;:0.0302},{&quot;_1&quot;:-2771758800000,&quot;_2&quot;:0.0682},{&quot;_1&quot;:-2769080400000,&quot;_2&quot;:-0.1289},{&quot;_1&quot;:-2766488400000,&quot;_2&quot;:-0.1516},{&quot;_1&quot;:-2763810000000,&quot;_2&quot;:-0.1458},{&quot;_1&quot;:-2761218000000,&quot;_2&quot;:-0.0707},{&quot;_1&quot;:-2758539600000,&quot;_2&quot;:-0.0079},{&quot;_1&quot;:-2755861200000,&quot;_2&quot;:0.0019},{&quot;_1&quot;:-2753269200000,&quot;_2&quot;:-0.214},{&quot;_1&quot;:-2750590800000,&quot;_2&quot;:-0.1315},{&quot;_1&quot;:-2747998800000,&quot;_2&quot;:-0.1785},{&quot;_1&quot;:-2745320400000,&quot;_2&quot;:-0.2735},{&quot;_1&quot;:-2742642000000,&quot;_2&quot;:-0.2987},{&quot;_1&quot;:-2740222800000,&quot;_2&quot;:-0.1369},{&quot;_1&quot;:-2737544400000,&quot;_2&quot;:-0.1791},{&quot;_1&quot;:-2734952400000,&quot;_2&quot;:-0.1469},{&quot;_1&quot;:-2732274000000,&quot;_2&quot;:-0.012},{&quot;_1&quot;:-2729682000000,&quot;_2&quot;:-0.0878},{&quot;_1&quot;:-2727003600000,&quot;_2&quot;:-0.0542},{&quot;_1&quot;:-2724325200000,&quot;_2&quot;:-0.1519},{&quot;_1&quot;:-2721733200000,&quot;_2&quot;:-0.1683},{&quot;_1&quot;:-2719054800000,&quot;_2&quot;:-0.1745},{&quot;_1&quot;:-2716462800000,&quot;_2&quot;:-0.0802},{&quot;_1&quot;:-2713784400000,&quot;_2&quot;:-0.1926},{&quot;_1&quot;:-2711106000000,&quot;_2&quot;:-0.1528},{&quot;_1&quot;:-2708600400000,&quot;_2&quot;:-0.2132},{&quot;_1&quot;:-2705922000000,&quot;_2&quot;:-0.1913},{&quot;_1&quot;:-2703330000000,&quot;_2&quot;:-0.1362},{&quot;_1&quot;:-2700651600000,&quot;_2&quot;:-0.2052},{&quot;_1&quot;:-2698059600000,&quot;_2&quot;:-0.3101},{&quot;_1&quot;:-2695381200000,&quot;_2&quot;:-0.2788},{&quot;_1&quot;:-2692702800000,&quot;_2&quot;:-0.2346},{&quot;_1&quot;:-2690110800000,&quot;_2&quot;:-0.1841},{&quot;_1&quot;:-2687432400000,&quot;_2&quot;:-0.2788},{&quot;_1&quot;:-2684840400000,&quot;_2&quot;:-0.1579},{&quot;_1&quot;:-2682162000000,&quot;_2&quot;:-0.438},{&quot;_1&quot;:-2679483600000,&quot;_2&quot;:-0.2701},{&quot;_1&quot;:-2677064400000,&quot;_2&quot;:-0.1583},{&quot;_1&quot;:-2674386000000,&quot;_2&quot;:-0.2679},{&quot;_1&quot;:-2671794000000,&quot;_2&quot;:-0.2941},{&quot;_1&quot;:-2669115600000,&quot;_2&quot;:-0.3207},{&quot;_1&quot;:-2666523600000,&quot;_2&quot;:-0.2504},{&quot;_1&quot;:-2663845200000,&quot;_2&quot;:-0.2529},{&quot;_1&quot;:-2661166800000,&quot;_2&quot;:-0.2082},{&quot;_1&quot;:-2658574800000,&quot;_2&quot;:-0.1391},{&quot;_1&quot;:-2655896400000,&quot;_2&quot;:-0. ...
//       function(playground, _magictsChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictsChart,
//     "o": {"x":"_1","y":"_2","width":600,"height":400,"tickFormat":"%Y-%m-%d %H:%M:%S"}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonc3093f7b0ef370d0ff38f8e7664a302d&quot;,&quot;initialValue&quot;:&quot;100&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon394388e219047df8852c853aa730e903&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>

// %%
var cont = true
new Thread() {
  override def run = 
    tsS.foreach { l =>
    if (cont) {
      Thread.sleep(1000)
      dynTC.addAndApply(l)
    }
  }
}.start
// Out:
// cont: Boolean = true

// %%
cont = false
// Out:
// cont: Boolean = false

// %% [markdown]
// ### Components

// %%
val rteam = shuffle(team.toList).take(5)
val dd = new DropDown("All" :: rteam.map(_.Player))
val rc = RadarChart(rteam, labelField=Some("Player"), sizes=(800, 600))
val bout = out

dd.selected --> Connection.fromObserver { p =>
  bout(p + " is selected")
  rc.applyOn(rc.originalData.filter(_.Player == p || p == "All"))
}

dd ++ bout ++ rc
// Out:
// rteam: List[TeamMember] = List(TeamMember(Boris Diaw,33,52.7,36.199999999999996,56.39999999999999,56.00000000000001,73.7), TeamMember(Tim Duncan,39,48.8,0.0,49.0,48.8,70.19999999999999), TeamMember(Patrick Mills,27,42.5,38.4,46.9,52.5,81.0), TeamMember(Rasual Butler,36,47.099999999999994,30.599999999999998,61.8,54.300000000000004,68.8), TeamMember(Jonathon Simmons,26,50.4,38.3,53.300000000000004,54.1,75.0))
// dd: notebook.front.widgets.DropDown[String] = <DropDown widget>
// rc: notebook.front.widgets.charts.RadarChart[List[TeamMember]] = <RadarChart widget>
// bout: notebook.front.widgets.OutDiv = <OutDiv widget>
// res104: notebook.front.Widget = <widget>
// <select data-bind="options: options, optionsText: 'text', optionsValue: 'index', value: selectedIndex, fireChange: true">
//       <script data-this="{&quot;optionsId&quot;:&quot;anonf2bef3fe847e1bb0d0cd3aa070521d46&quot;,&quot;selectedIndexId&quot;:&quot;anond06ecbc7ac6eaf4796f5e89722ce560d&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req( ['observable', 'knockout'],
//   function (O, ko) {
//     ko.applyBindings({
//       options: O.makeObservableArray(optionsId),
//       selectedIndex: O.makeObservable(selectedIndexId)
//     },
//     this);
//   }
// );/*]]>*/</script>
//     </select><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anond5fc18e9da5d091901677125d3bca9e7&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p><div>
//       <script data-this="{&quot;dataId&quot;:&quot;anond71d05f7fa15c9a21405d8cc467bb9b4&quot;,&quot;dataInit&quot;:[{&quot;Player&quot;:&quot;Boris Diaw&quot;,&quot;FT_pc&quot;:73.7,&quot;_3P_pc&quot;:36.199999999999996,&quot;_2P_pc&quot;:56.39999999999999,&quot;Age&quot;:33,&quot;eFG_pc&quot;:56.00000000000001,&quot;FG_pc&quot;:52.7},{&quot;Player&quot;:&quot;Tim Duncan&quot;,&quot;FT_pc&quot;:70.19999999999999,&quot;_3P_pc&quot;:0.0,&quot;_2P_pc&quot;:49.0,&quot;Age&quot;:39,&quot;eFG_pc&quot;:48.8,&quot;FG_pc&quot;:48.8},{&quot;Player&quot;:&quot;Patrick Mills&quot;,&quot;FT_pc&quot;:81.0,&quot;_3P_pc&quot;:38.4,&quot;_2P_pc&quot;:46.9,&quot;Age&quot;:27,&quot;eFG_pc&quot;:52.5,&quot;FG_pc&quot;:42.5},{&quot;Player&quot;:&quot;Rasual Butler&quot;,&quot;FT_pc&quot;:68.8,&quot;_3P_pc&quot;:30.599999999999998,&quot;_2P_pc&quot;:61.8,&quot;Age&quot;:36,&quot;eFG_pc&quot;:54.300000000000004,&quot;FG_pc&quot;:47.099999999999994},{&quot;Player&quot;:&quot;Jonathon Simmons&quot;,&quot;FT_pc&quot;:75.0,&quot;_3P_pc&quot;:38.3,&quot;_2P_pc&quot;:53.300000000000004,&quot;Age&quot;:26,&quot;eFG_pc&quot;:54.1,&quot;FG_pc&quot;:50.4}],&quot;genId&quot;:&quot;2023515092&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/radarChart'],
//       function(playground, _magicradarChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicradarChart,
//     "o": {"classCol":"Player","axisCols":["Age","FG_pc","_3P_pc","_2P_pc","eFG_pc","FT_pc"],"width":800,"height":600}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anona3cdd29fcadd0c578015e2465b6d6d57&quot;,&quot;initialValue&quot;:&quot;5&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon55c428e6464f8f975d8b2c196c71bfc1&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>

// %% [markdown]
// ---
// ## Synchronization

// %% [markdown]
// Oh... notebooks are synchronized!
//
// Open another browser window and relaunch the timeseries example.

// %% [markdown]
// ---
// ## Create new chart type... live

// %% [markdown]
// If you want/need to exerce your js fu, you can always use the `Chart` (for instance) API to create new dynamic widgets types.
//
// In the following, we'll create a widget that can plot duration bars based for given operations (only a name):
// * a `js` string which is the javascript to execute for the new chart. It:
//   * has to be a function with 3 params
//     * `dataO` a knockout observable wich can be listened for new incoming data, see the `subscribe` call
//     * `container` is the div element where you can add new elements
//     * `options` is an extra object passed to the widget which defines additional configuration options (like width or a specific color or whatever)
//   * has a `this` object containing:
//     * `dataInit` this is the JSON representation of the Scala data as an array of objects having the same schema as the Scala type
//     * `genId` a unique id that you can use for a high level element for instance

// %%
val js = """
function progressgraph (dataO, container, options) {
  var css = 'div.prog {position: relative; overflow: hidden; } span.pp {display: inline-block; position: absolute; height: 16px;} span.prog {display: inline-block; position: absolute; height: 16px; }' +
            '.progs {border: solid 1px #ccc; background: #eee; } .progs .pv {background: #3182bd; }',
      head = document.head || document.getElementsByTagName('head')[0],
      style = document.createElement('style');

  style.type = 'text/css';
  if (style.styleSheet){
    style.styleSheet.cssText = css;
  } else {
    style.appendChild(document.createTextNode(css));
  }

  head.appendChild(style);


  var width = options.width||600
  var height = options.height||400
  
  function create(name, duration) {
    var div =  d3.select(container).append("div").attr("class", "prog");

    div.append("span").attr("class", "pp prog")
        .style("width", "74px")
        .style("text-align", "right")
        .style("z-index", "2000")
        .text(name);

    div.append("span")
        .attr("class", "progs")
        .style("width", "240px")
        .style("left", "80px")
      .append("span")
        .attr("class", "pp pv")
      .transition()
        .duration(duration)
        .ease("linear")
        .style("width", "350px");

    div.transition()
        .style("height", "20px")
      .transition()
        .delay(duration)
        .style("height", "0px")
        .remove();

  }

  function onData(data) {
    _.each(data, function(d) {
      create(d[options.name], 5000 + d[options.duration])
    });
  }

  onData(this.dataInit);
  dataO.subscribe(onData);
}
""".trim
// Out:
// js: String =
// function progressgraph (dataO, container, options) {
//   var css = 'div.prog {position: relative; overflow: hidden; } span.pp {display: inline-block; position: absolute; height: 16px;} span.prog {display: inline-block; position: absolute; height: 16px; }' +
//             '.progs {border: solid 1px #ccc; background: #eee; } .progs .pv {background: #3182bd; }',
//       head = document.head || document.getElementsByTagName('head')[0],
//       style = document.createElement('style');
//
//   style.type = 'text/css';
//   if (style.styleSheet){
//     style.styleSheet.cssText = css;
//   } else {
//     style.appendChild(document.createTextNode(css));
//   }
//
//   head.appendChild(style);
//
//
//   var width = options.width||600
//   var height = options.height||400
//
//   function create(name, duration) {
//     var div ...

// %% [markdown]
// Now we can create the widget extending `notebook.front.widgets.charts.Chart[C]`, where `C` is any Scala type, it'll be converted to JS using the implicit instance of `ToPoints`.
//
// It has to declare the original dataset which needs to be a wrapper (`List`, `Array`, ...) of the `C` instances we want to plot. But it can also define other things like below:
// * `sizes` are the $w \times h$ dimension of the chart
// * `maxPoints` the number of points to plot, the way to select them is defined in the implicitly available instance of `Sampler`.
// * `scripts` a list of references to existing javascript scripts
// * `snippets` a list of string that represent snippets to execute in JS, they take the form of a JSON object with
//   * `f` the function to call when the snippet will be executed
//   * `o` a JSON object that will be provided to the above function at execution time. Here we define which field has to be used for the name and duration.

// %%
import notebook.front.widgets._
import notebook.front.widgets.magic._
import notebook.front.widgets.magic.Implicits._
import notebook.front.widgets.magic.SamplerImplicits._
case class ProgChart[C:ToPoints:Sampler](
  originalData:C,
  override val sizes:(Int, Int)=(600, 400),
  maxPoints:Int = 1000,
  name:String,
  duration:String
) extends notebook.front.widgets.charts.Chart[C](originalData, maxPoints) {
  def mToSeq(t:MagicRenderPoint):Seq[(String, Any)] = t.data.toSeq


  override val snippets = List(s"""|{
                                   |  "f": $js, 
                                   |  "o": {
                                   |    "name": "$name",
                                   |    "duration": "$duration"
                                   |  }
                                   |}
                                  """.stripMargin)
  
  override val scripts = Nil
}
// Out:
// import notebook.front.widgets._
// import notebook.front.widgets.magic._
// import notebook.front.widgets.magic.Implicits._
// import notebook.front.widgets.magic.SamplerImplicits._
// defined class ProgChart

// %% [markdown]
// We can define the type of data we'll use for this example

// %%
case class ProgData(n:String, v:Int)
// Out:
// defined class ProgData

// %% [markdown]
// Here we generate a bunch of data bucketized by 10, and we create an instance of the new widget giving it the first bucket of data and specifying the right field names for `name` and `duration`.

// %%
import scala.util.Random
val pdata = for {
  c1 <- 'a' to 'e'
  c2 <- 'a' to 'e'
} yield ProgData(""+c1+c2, (Random.nextDouble * 10000).toInt)
val pdataH :: pdataS = pdata.toList.sliding(10, 10).toList

val pc = ProgChart(pdataH, name = "n", duration = "v")
pc
// Out:
// import scala.util.Random
// pdata: scala.collection.immutable.IndexedSeq[ProgData] = Vector(ProgData(aa,1556), ProgData(ab,504), ProgData(ac,3887), ProgData(ad,4116), ProgData(ae,8454), ProgData(ba,9980), ProgData(bb,1191), ProgData(bc,1007), ProgData(bd,9926), ProgData(be,3612), ProgData(ca,8337), ProgData(cb,8970), ProgData(cc,1357), ProgData(cd,6919), ProgData(ce,1689), ProgData(da,3236), ProgData(db,4788), ProgData(dc,5859), ProgData(dd,8475), ProgData(de,489), ProgData(ea,6193), ProgData(eb,4423), ProgData(ec,7244), ProgData(ed,8974), ProgData(ee,7681))
// pdataH: List[ProgData] = List(ProgData(aa,1556), ProgData(ab,504), ProgData(ac,3887), ProgData(ad,4116), ProgData(ae,8454), ProgData(ba,9980), ProgData(bb,1191), ProgData(bc,1007), ProgData(bd,9926), ProgData(be,3612))
// pdataS: List[Lis...
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon372c891f932c397483528ea0398bf5fd&quot;,&quot;dataInit&quot;:[{&quot;n&quot;:&quot;aa&quot;,&quot;v&quot;:1556},{&quot;n&quot;:&quot;ab&quot;,&quot;v&quot;:504},{&quot;n&quot;:&quot;ac&quot;,&quot;v&quot;:3887},{&quot;n&quot;:&quot;ad&quot;,&quot;v&quot;:4116},{&quot;n&quot;:&quot;ae&quot;,&quot;v&quot;:8454},{&quot;n&quot;:&quot;ba&quot;,&quot;v&quot;:9980},{&quot;n&quot;:&quot;bb&quot;,&quot;v&quot;:1191},{&quot;n&quot;:&quot;bc&quot;,&quot;v&quot;:1007},{&quot;n&quot;:&quot;bd&quot;,&quot;v&quot;:9926},{&quot;n&quot;:&quot;be&quot;,&quot;v&quot;:3612}],&quot;genId&quot;:&quot;1296947449&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground'],
//       function(playground) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//
//
//                         ,
//                         {
//   "f": function progressgraph (dataO, container, options) {
//   var css = 'div.prog {position: relative; overflow: hidden; } span.pp {display: inline-block; position: absolute; height: 16px;} span.prog {display: inline-block; position: absolute; height: 16px; }' +
//             '.progs {border: solid 1px #ccc; background: #eee; } .progs .pv {background: #3182bd; }',
//       head = document.head || document.getElementsByTagName('head')[0],
//       style = document.createElement('style');
//
//   style.type = 'text/css';
//   if (style.styleSheet){
//     style.styleSheet.cssText = css;
//   } else {
//     style.appendChild(document.createTextNode(css));
//   }
//
//   head.appendChild(style);
//
//
//   var width = options.width||600
//   var height = options.height||400
//
//   function create(name, duration) {
//     var div =  d3.select(container).append("div").attr("class", "prog");
//
//     div.append("span").attr("class", "pp prog")
//         .style("width", "74px")
//         .style("text-align", "right")
//         .style("z-index", "2000")
//         .text(name);
//
//     div.append("span")
//         .attr("class", "progs")
//         .style("width", "240px")
//         .style("left", "80px")
//       .append("span")
//         .attr("class", "pp pv")
//       .transition()
//         .duration(duration)
//         .ease("linear")
//         .style("width", "350px");
//
//     div.transition()
//         .style("height", "20px")
//       .transition()
//         .delay(duration)
//         .style("height", "0px")
//         .remove();
//
//   }
//
//   function onData(data) {
//     _.each(data, function(d) {
//       create(d[options.name], 5000 + d[options.duration])
//     });
//   }
//
//   onData(this.dataInit);
//   dataO.subscribe(onData);
// },
//   "o": {
//     "name": "n",
//     "duration": "v"
//   }
// }
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anona5b4763ee6709ebd6cefa4316652f7c9&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon79f31feded14666492ee453ea478cf97&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>

// %% [markdown]
// We update the chart by passing the value using the `addAndApply` approach.

// %%
var pcont = true
new Thread() {
  override def run = 
    pdataS.foreach { l =>
    if (pcont) {
      Thread.sleep(9000)
      pc.addAndApply(l, true)
    }
  }
}.start
// Out:
// pcont: Boolean = true

// %% [markdown]
// ---
// ## Contexts with interpolation

// %%
:sh ls ${sys.env("NOTEBOOKS_DIR")}

// %%
val ok = "$\\LaTeX$ interpolated in Scala is $\\Re$"

// %%
:markdown 
Yup, **$ok** in Spark Notebook

// %%
:javascript
alert("I am ${("whoami".!!).trim}")

// %% [markdown]
// ---
// ## Metadata

// %% [markdown]
// A notebook has a context enricheded via its metadata, here are a few important ones.

// %% [markdown]
// ---
// ## Logs

// %% [markdown]
// Checking logs is always painful when using a notebook since this is simply a web client on the remote REPL in the server.
//
// Hence the logs are quite far, or even worse inaccessible!
//
// So, the spark notebook will forwards **all logs using slf4j** to the browser console → go check it, use the `F12` key and open the _console_ tab!
